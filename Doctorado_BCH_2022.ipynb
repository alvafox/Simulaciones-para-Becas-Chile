# %% [markdown]
# <a href="https://colab.research.google.com/github/alvafox/Simulaciones-para-Becas-Chile/blob/main/Doctorado_BCH_2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **DOCTORADO BCH 2022**
# ---
#
#
# **Instrucción:** Para Doctorado se quiere igualar la ponderación de AAP a 30% (-5%), para entregar más a la retribución (+5%).
#
# **Hallazgos:** Al redistribuir un 5% del puntaje otorgado a los AAP y destinarlo a la Retribución (2.3), finalmente el número de seleccionados aumenta levemente.
#
# - Es importante remarcar que de 206 seleccionados, se pasa a 211 (+2%).
# - Una menor ponderación sobre los AAP favorece el puntaje final de los postulantes, lo que eventualmente podría impactar en puntajes de corte más altos, pero sin tener un efecto "importante" (línea verde en 45º).
#
# ![image.png](data:image/png;base64,...)
#
# - El concurso se vuelve levemente más competitivo, dado que la redistrubución de la ponderación se incorpora a un subcriterio que tiene un desempeño promedio mayor.
#
# ```
# 	              DELTA
# SUBE PUNTAJE	    194
# BAJA PUNTAJE	    120
# FUERA DE BASES	   45
# MANTIENE	          2
# ```
#
# ```
# 	               count	mean	 std	  min	  25%	  50%	  75%	  max
#             AAP	316.0	4.069	0.671	1.589	3.688	4.262	4.545	5.0
# SUBCRITERIO 1.2	316.0	4.281	0.678	1.500	4.000	4.500	5.000	5.0
# SUBCRITERIO 1.3	316.0	4.520	0.571	2.500	4.250	4.750	5.000	5.0
# SUBCRITERIO 2.1	316.0	4.074	0.773	1.750	3.500	4.250	4.750	5.0
# SUBCRITERIO 2.2	316.0	4.341	0.694	1.750	4.000	4.500	5.000	5.0
# SUBCRITERIO 2.3	316.0	4.299	0.711	1.750	3.787	4.500	5.000	5.0
# SUBCRITERIO 3.1	316.0	4.159	1.332	0.000	4.000	4.919	5.000	5.0
# ```
#
#
#
#
# - Bajo el supuesto de mantener el puntaje de corte, al realizar la distribución se estarían otorgando más becas.
# - Notar que al ser un concurso con un volumen de adjudicación bajo, en comparación a los concursos nacionales, el efecto de las brechas de género en cada comité, pierde relevancia (son números muy pequeños).
# - A nivel concurso, la nueva ponderación favorece al género masculino (de 85 a 91 adjudicados), pero de igual forma la adjudicación se mantiene a favor del género femenino (de 121 a 120 adjudicados).

# %%
# !pip install matplotlib==3.4.0

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.set_option('max_rows', 200)
pd.set_option('precision', 3)

# %%
df_doc = pd.read_csv("/content/DOC BCH 2022.csv", sep=";",encoding="latin-1", decimal=",")

# %%
df_doc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 361 entries, 0 to 360
# Data columns (total 37 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   FOLIO                        361 non-null    int64
#  1   COMITÉ                       361 non-null    object
#  2   Área OCDE                    361 non-null    object
#  3   ESTADO ADMISIBILIDAD         361 non-null    object
#  4   NOTA PREGRADO                361 non-null    float64
#  5   TIPO RANKING                 361 non-null    object
#  6   RANKING                      361 non-null    int64
#  7   TOTAL                        361 non-null    int64
#  8   % RANKING                    361 non-null    float64
#  9   Y                            361 non-null    float64
#  10  P                            361 non-null    float64
#  11  PQ                           361 non-null    float64
#  12  Q                            361 non-null    float64
#  13  Rx                           361 non-null    float64
#  14  Intervalo                    361 non-null    object
#  15  AAP                          361 non-null    float64
#  16  SUBCRITERIO 1.2              316 non-null    float64
#  17  SUBCRITERIO 1.3              316 non-null    float64
#  18  SUBCRITERIO 2.1              316 non-null    float64
#  19  SUBCRITERIO 2.2              316 non-null    float64
#  20  SUBCRITERIO 2.3              316 non-null    float64
#  21  SUBCRITERIO 3.1              353 non-null    float64
#  22  Bonificaciones-Etnia         361 non-null    float64
#  23  Bonificaciones-Región        361 non-null    float64
#  24  Bonificaciones-Discapacidad  361 non-null    float64
#  25  Bonificaciones-Reparación    361 non-null    float64
#  26  Bonificación Final           361 non-null    float64
#  27  AAFF                         361 non-null    object
#  28  PUNTAJE_FINAL                361 non-null    float64
#  29  PUNTAJE_FINAL_NP             361 non-null    float64
#  30  ESTADO_FINAL                 361 non-null    object
#  31  ESTADO_FINAL_NP              361 non-null    object
#  32  DELTA                        361 non-null    object
#  33  FECHA NAC                    361 non-null    object
#  34  EDAD                         361 non-null    int64
#  35  RANGO                        361 non-null    object
#  36  GÉNERO                       361 non-null    object
# dtypes: float64(21), int64(4), object(12)
# memory usage: 104.5+ KB

# %%
df_doc
# Out:
#         FOLIO                         COMITÉ                Área OCDE  \
# 0    72220001  Ecología y Ciencias Naturales       CIENCIAS NATURALES
# 1    72220002                         Letras              HUMANIDADES
# 2    72220003                    Educación I        CIENCIAS SOCIALES
# 3    72220004   Biología Celular y Molecular       CIENCIAS NATURALES
# 4    72220005                    Educación I        CIENCIAS SOCIALES
# ..        ...                            ...                      ...
# 356  72220357                       Economía        CIENCIAS SOCIALES
# 357  72220358                         Letras              HUMANIDADES
# 358  72220359         Cs. de la Ingeniería I  INGENIERIA Y TECNOLOGIA
# 359  72220360                   Arquitectura              HUMANIDADES
# 360  72220361                       Economía        CIENCIAS SOCIALES
#
#     ESTADO ADMISIBILIDAD  NOTA PREGRADO TIPO RANKING  RANKING  TOTAL  \
# 0              ADMISIBLE           6.30       EGRESO        2     52
# 1              ADMISIBLE           6.44       EGRESO        2    116
# 2              ADMISIBLE           6.04       EGRESO       16     37
# 3              ADMISIBLE           6.04       TITULO        2     49
# 4              ADMISIBLE           5.85       EGRESO        6     23
# ..                   ...            ...          ...      ...    ...
# 356       FUERA DE BASES           5.00       TITULO        8    120
# 357            ADMISIBLE           6.50       EGRESO        2     14
# 358            ADMISIBLE           5.82       TITULO        3     61
# 359            ADMISIBLE           5.30       EGRESO       86    148
# 360            ADMISIBLE           5.09       EGRESO       18     22
#
#      % RANKING      Y  ...  AAFF  PUNTAJE_FINAL  PUNTAJE_FINAL_NP  \
# 0        3.846  4.444  ...    SI          4.682             4.660
# 1        1.724  4.565  ...     -          3.884             3.845
# 2       43.243  4.205  ...     -          4.227             4.219
# 3        4.082  4.205  ...     -          4.870             4.892
# 4       26.087  4.017  ...     -          4.339             4.325
# ..         ...    ...  ...   ...            ...               ...
# 356      6.667  0.000  ...     -          0.000             0.000
# 357     14.286  4.615  ...     -          4.753             4.748
# 358      4.918  3.986  ...     -          4.440             4.442
# 359     58.108  3.396  ...     -          2.522             2.542
# 360     81.818  3.124  ...     -          3.308             3.289
#
#         ESTADO_FINAL  ESTADO_FINAL_NP           DELTA   FECHA NAC  EDAD  \
# 0       SELECCIONADA     SELECCIONADA            BAJA  09-06-1983    39
# 1    NO SELECCIONADA  NO SELECCIONADA            BAJA  30-09-1989    32
# 2       SELECCIONADA     SELECCIONADA            BAJA  03-08-1993    28
# 3       SELECCIONADA     SELECCIONADA            SUBE  06-02-1989    33
# 4       SELECCIONADA     SELECCIONADA            BAJA  07-07-1974    47
# ..               ...              ...             ...         ...   ...
# 356   FUERA DE BASES   FUERA DE BASES  FUERA DE BASES  11-07-1986    35
# 357     SELECCIONADA     SELECCIONADA            BAJA  04-09-1990    31
# 358     SELECCIONADA     SELECCIONADA            SUBE  29-11-1993    28
# 359  NO SELECCIONADA  NO SELECCIONADA            SUBE  12-11-1991    30
# 360  NO SELECCIONADA  NO SELECCIONADA            BAJA  24-11-1988    33
#
#         RANGO     GÉNERO
# 0    [35, 40[  Masculino
# 1    [30, 35[  Masculino
# 2    [25, 30[   Femenino
# 3    [30, 35[  Masculino
# 4     [45 + [   Femenino
# ..        ...        ...
# 356  [35, 40[   Femenino
# 357  [30, 35[  Masculino
# 358  [25, 30[  Masculino
# 359  [30, 35[   Femenino
# 360  [30, 35[  Masculino
#
# [361 rows x 37 columns]

# %% [markdown]
# # **TODOS LOS PUNTAJES**

# %%
import numpy as np 

df_adm = df_doc[df_doc['ESTADO ADMISIBILIDAD'] != 'FUERA DE BASES']

plt.style.use('ggplot')
# Calcular la correlación entre x e y
corr = df_adm['PUNTAJE_FINAL'].corr(df_adm['PUNTAJE_FINAL_NP'])
m, b = np.polyfit(df_adm['PUNTAJE_FINAL'], df_adm['PUNTAJE_FINAL_NP'], 1)

df_adm.plot(kind='scatter', x='PUNTAJE_FINAL', y='PUNTAJE_FINAL_NP',figsize=(8, 8))
plt.plot(df_adm['PUNTAJE_FINAL'], m*df_adm['PUNTAJE_FINAL'] + b, color='red')
plt.plot([2.5, 5], [2.5,5], color='green') # Lìnea de identidad
plt.title('Correlación entre PUNTAJE_FINAL y PUNTAJE_FINAL_NP (Corr = {:.2f})'.format(corr))
plt.show()

# %% [markdown]
# ## **SUBEN DE PUNTAJE**

# %%
df_adm = df_doc[(df_doc['ESTADO ADMISIBILIDAD'] != 'FUERA DE BASES') & (df_doc['DELTA'] == 'SUBE')]

plt.style.use('ggplot')
# Calcular la correlación entre x e y
corr = df_adm['PUNTAJE_FINAL'].corr(df_adm['PUNTAJE_FINAL_NP'])
m, b = np.polyfit(df_adm['PUNTAJE_FINAL'], df_adm['PUNTAJE_FINAL_NP'], 1)

df_adm.plot(kind='scatter', x='PUNTAJE_FINAL', y='PUNTAJE_FINAL_NP',figsize=(8, 8))
#plt.plot(df_adm['PUNTAJE_FINAL'], m*df_adm['PUNTAJE_FINAL'] + b, color='red')
plt.plot([2.5, 5], [2.5,5], color='gray') # Lìnea de identidad
plt.title('Correlación entre PUNTAJE_FINAL y PUNTAJE_FINAL_NP (Corr = {:.2f})'.format(corr))
plt.show()

# %% [markdown]
# ## **MANTIENEN PUNTAJE**

# %%
df_adm = df_doc[(df_doc['ESTADO ADMISIBILIDAD'] != 'FUERA DE BASES') & (df_doc['DELTA'] == 'MANTIENE')]

plt.style.use('ggplot')
# Calcular la correlación entre x e y
corr = df_adm['PUNTAJE_FINAL'].corr(df_adm['PUNTAJE_FINAL_NP'])
m, b = np.polyfit(df_adm['PUNTAJE_FINAL'], df_adm['PUNTAJE_FINAL_NP'], 1)

df_adm.plot(kind='scatter', x='PUNTAJE_FINAL', y='PUNTAJE_FINAL_NP',figsize=(8, 8))
#plt.plot(df_adm['PUNTAJE_FINAL'], m*df_adm['PUNTAJE_FINAL'] + b, color='red')
plt.plot([2.5, 5], [2.5,5], color='gray') # Lìnea de identidad
plt.title('Correlación entre PUNTAJE_FINAL y PUNTAJE_FINAL_NP (Corr = {:.2f})'.format(corr))
plt.show()

# %% [markdown]
# ## **BAJAN DE PUNTAJE**

# %%
df_adm = df_doc[(df_doc['ESTADO ADMISIBILIDAD'] != 'FUERA DE BASES') & (df_doc['DELTA'] == 'BAJA')]

plt.style.use('ggplot')
# Calcular la correlación entre x e y
corr = df_adm['PUNTAJE_FINAL'].corr(df_adm['PUNTAJE_FINAL_NP'])
m, b = np.polyfit(df_adm['PUNTAJE_FINAL'], df_adm['PUNTAJE_FINAL_NP'], 1)

df_adm.plot(kind='scatter', x='PUNTAJE_FINAL', y='PUNTAJE_FINAL_NP',figsize=(8, 8))
#plt.plot(df_adm['PUNTAJE_FINAL'], m*df_adm['PUNTAJE_FINAL'] + b, color='red')
plt.plot([2.5, 5], [2.5,5], color='gray') # Lìnea de identidad
plt.title('Correlación entre PUNTAJE_FINAL y PUNTAJE_FINAL_NP (Corr = {:.2f})'.format(corr))
plt.show()

# %%
df_doc["DELTA"].value_counts()
# Out:
# SUBE              194
# BAJA              120
# FUERA DE BASES     45
# MANTIENE            2
# Name: DELTA, dtype: int64

# %%
df_doc["DELTA"].value_counts('%')*100
# Out:
# SUBE              53.740
# BAJA              33.241
# FUERA DE BASES    12.465
# MANTIENE           0.554
# Name: DELTA, dtype: float64

# %%
df_doc["ESTADO_FINAL"].value_counts()
# Out:
# SELECCIONADA       206
# NO SELECCIONADA    110
# FUERA DE BASES      45
# Name: ESTADO_FINAL, dtype: int64

# %%
df_doc["ESTADO_FINAL"].value_counts("%")
# Out:
# SELECCIONADA       0.571
# NO SELECCIONADA    0.305
# FUERA DE BASES     0.125
# Name: ESTADO_FINAL, dtype: float64

# %%
df_doc["ESTADO_FINAL_NP"].value_counts()
# Out:
# SELECCIONADA       211
# NO SELECCIONADA    105
# FUERA DE BASES      45
# Name: ESTADO_FINAL_NP, dtype: int64

# %%
df_doc["ESTADO_FINAL_NP"].value_counts("%")
# Out:
# SELECCIONADA       0.584
# NO SELECCIONADA    0.291
# FUERA DE BASES     0.125
# Name: ESTADO_FINAL_NP, dtype: float64

# %%
df_doc.groupby(['ESTADO_FINAL'])['GÉNERO'].value_counts().unstack(1)
# Out:
# GÉNERO           Femenino  Masculino
# ESTADO_FINAL
# FUERA DE BASES         19         26
# NO SELECCIONADA        47         63
# SELECCIONADA          121         85

# %%
df_doc.groupby(['ESTADO_FINAL_NP'])['GÉNERO'].value_counts().unstack(1)
# Out:
# GÉNERO           Femenino  Masculino
# ESTADO_FINAL_NP
# FUERA DE BASES         19         26
# NO SELECCIONADA        48         57
# SELECCIONADA          120         91

# %%
df_doc2 = df_doc[df_doc["ESTADO ADMISIBILIDAD"] == "ADMISIBLE"]
df_doc2[["AAP","SUBCRITERIO 1.2", "SUBCRITERIO 1.3", "SUBCRITERIO 2.1", "SUBCRITERIO 2.2","SUBCRITERIO 2.3", "SUBCRITERIO 3.1"]].describe().T
# Out:
#                  count   mean    std    min    25%    50%    75%  max
# AAP              316.0  4.069  0.671  1.589  3.688  4.262  4.545  5.0
# SUBCRITERIO 1.2  316.0  4.281  0.678  1.500  4.000  4.500  5.000  5.0
# SUBCRITERIO 1.3  316.0  4.520  0.571  2.500  4.250  4.750  5.000  5.0
# SUBCRITERIO 2.1  316.0  4.074  0.773  1.750  3.500  4.250  4.750  5.0
# SUBCRITERIO 2.2  316.0  4.341  0.694  1.750  4.000  4.500  5.000  5.0
# SUBCRITERIO 2.3  316.0  4.299  0.711  1.750  3.787  4.500  5.000  5.0
# SUBCRITERIO 3.1  316.0  4.159  1.332  0.000  4.000  4.919  5.000  5.0

# %% [markdown]
# Tanto el promedio (4.069) como la mediana (4.262) de los AAP son menores al promedio (4.299) y mediana (4.500) del subcriterio 2.3. esto significa que al otogar mayor ponderación a este subcriterio, el puntaje promedio del grupo deberia subir levemente. Esto se observó en los calculos anteriores, pero su efecto es acotado debido a que se redistribuye una ponderación relativamente baja.

# %%
import numpy as np

bins = np.arange(0, 5.6, 0.1)
bins = bins.round(3).tolist()

bins

# %% [markdown]
# # Admisibles (PUNTAJE FINAL)

# %%
plt.style.use('ggplot')

#bins = [0.000, 0.250, 0.500, 0.750, 1.000, 1.250, 1.500, 1.750, 2.000, 2.250, 2.500, 2.750, 3.000, 3.250, 3.500, 3.750, 4.000, 4.250, 4.500, 4.750, 5.000, 5.250, 5.500]

plt.figure(figsize=(16, 4.5))
counts, edges, bars = plt.hist(df_doc[["PUNTAJE_FINAL"]], bins=bins, edgecolor='k', facecolor='#1f77b4')

plt.title("PUNTAJE FINAL")
plt.bar_label(bars)

plt.figure(figsize=(16, 4.5))
counts, edges, bars = plt.hist(df_doc[["PUNTAJE_FINAL_NP"]], bins=bins, edgecolor='k', facecolor='#1f77b4')

plt.title("PUNTAJE FINAL (NUEVA PONDERACION)")
plt.bar_label(bars)
# Out:
# [Text(0, 0, '45'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '2'),
#  Text(0, 0, '2'),
#  Text(0, 0, '3'),
#  Text(0, 0, '2'),
#  Text(0, 0, '5'),
#  Text(0, 0, '6'),
#  Text(0, 0, '6'),
#  Text(0, 0, '5'),
#  Text(0, 0, '4'),
#  Text(0, 0, '17'),
#  Text(0, 0, '11'),
#  Text(0, 0, '15'),
#  Text(0, 0, '26'),
#  Text(0, 0, '22'),
#  Text(0, 0, '25'),
#  Text(0, 0, '21'),
#  Text(0, 0, '31'),
#  Text(0, 0, '28'),
#  Text(0, 0, '33'),
#  Text(0, 0, '27'),
#  Text(0, 0, '17'),
#  Text(0, 0, '5'),
#  Text(0, 0, '2'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0')]

# %% [markdown]
# # ADMISIBLES POR GÉNERO

# %%
plt.style.use('ggplot')

#bins = [0.000, 0.250, 0.500, 0.750, 1.000, 1.250, 1.500, 1.750, 2.000, 2.250, 2.500, 2.750, 3.000, 3.250, 3.500, 3.750, 4.000, 4.250, 4.500, 4.750, 5.000, 5.250, 5.500]

plt.figure(figsize=(16, 4.5))
counts, edges, bars = plt.hist(df_doc[df_doc["GÉNERO"] == "Masculino"][["PUNTAJE_FINAL"]], bins=bins, edgecolor='k', facecolor='#1f77b4')

plt.title("PUNTAJE FINAL - Masculino")
plt.bar_label(bars)

plt.figure(figsize=(16, 4.5))
counts, edges, bars = plt.hist(df_doc[df_doc["GÉNERO"] == "Masculino"][["PUNTAJE_FINAL_NP"]], bins=bins, edgecolor='k', facecolor='#1f77b4')

plt.title("PUNTAJE FINAL - Masculino (NUEVA PONDERACION)")
plt.bar_label(bars)


plt.figure(figsize=(16, 4.5))
counts, edges, bars = plt.hist(df_doc[df_doc["GÉNERO"] == "Femenino"][["PUNTAJE_FINAL"]], bins=bins, edgecolor='k', facecolor='#1f77b4')

plt.title("PUNTAJE FINAL - Femenino")
plt.bar_label(bars)

plt.figure(figsize=(16, 4.5))
counts, edges, bars = plt.hist(df_doc[df_doc["GÉNERO"] == "Femenino"][["PUNTAJE_FINAL_NP"]], bins=bins, edgecolor='k', facecolor='#1f77b4')

plt.title("PUNTAJE FINAL - Femenino (NUEVA PONDERACION)")
plt.bar_label(bars)
# Out:
# [Text(0, 0, '19'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '2'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '2'),
#  Text(0, 0, '3'),
#  Text(0, 0, '1'),
#  Text(0, 0, '2'),
#  Text(0, 0, '8'),
#  Text(0, 0, '5'),
#  Text(0, 0, '6'),
#  Text(0, 0, '15'),
#  Text(0, 0, '10'),
#  Text(0, 0, '16'),
#  Text(0, 0, '13'),
#  Text(0, 0, '15'),
#  Text(0, 0, '13'),
#  Text(0, 0, '23'),
#  Text(0, 0, '17'),
#  Text(0, 0, '8'),
#  Text(0, 0, '3'),
#  Text(0, 0, '2'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0')]

# %% [markdown]
# # SELECCIONADAS

# %%
plt.style.use('ggplot')

#bins = [0.000, 0.250, 0.500, 0.750, 1.000, 1.250, 1.500, 1.750, 2.000, 2.250, 2.500, 2.750, 3.000, 3.250, 3.500, 3.750, 4.000, 4.250, 4.500, 4.750, 5.000, 5.250, 5.500]

plt.figure(figsize=(16, 4.5))
counts, edges, bars = plt.hist(df_doc[(df_doc["GÉNERO"] == "Masculino") & (df_doc["ESTADO_FINAL"] == "SELECCIONADA")][["PUNTAJE_FINAL"]], bins=bins, edgecolor='k', facecolor='#1f77b4')

plt.title("PUNTAJE FINAL - Masculino")
plt.bar_label(bars)

plt.figure(figsize=(16, 4.5))
counts, edges, bars = plt.hist(df_doc[(df_doc["GÉNERO"] == "Masculino") & (df_doc["ESTADO_FINAL"] == "SELECCIONADA")][["PUNTAJE_FINAL_NP"]], bins=bins, edgecolor='k', facecolor='#1f77b4')

plt.title("PUNTAJE FINAL - Masculino (NUEVA PONDERACION)")
plt.bar_label(bars)


plt.figure(figsize=(16, 4.5))
counts, edges, bars = plt.hist(df_doc[(df_doc["GÉNERO"] == "Masculino") & (df_doc["ESTADO_FINAL"] == "SELECCIONADA")][["PUNTAJE_FINAL"]], bins=bins, edgecolor='k', facecolor='#1f77b4')

plt.title("PUNTAJE FINAL - Femenino")
plt.bar_label(bars)

plt.figure(figsize=(16, 4.5))
counts, edges, bars = plt.hist(df_doc[(df_doc["GÉNERO"] == "Masculino") & (df_doc["ESTADO_FINAL"] == "SELECCIONADA")][["PUNTAJE_FINAL_NP"]], bins=bins, edgecolor='k', facecolor='#1f77b4')

plt.title("PUNTAJE FINAL - Femenino (NUEVA PONDERACION)")
plt.bar_label(bars)
# Out:
# [Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '6'),
#  Text(0, 0, '8'),
#  Text(0, 0, '8'),
#  Text(0, 0, '16'),
#  Text(0, 0, '15'),
#  Text(0, 0, '10'),
#  Text(0, 0, '10'),
#  Text(0, 0, '9'),
#  Text(0, 0, '2'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0')]

# %%
df_doc.groupby(["GÉNERO", pd.cut(df_doc.PUNTAJE_FINAL, bins, right=False, include_lowest=True)])["FOLIO"].count().unstack(0).style.background_gradient()
# Out:
# <style type="text/css">
# #T_e2d5b_row0_col0 {
#   background-color: #0c74b2;
#   color: #f1f1f1;
# }
# #T_e2d5b_row0_col1, #T_e2d5b_row46_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_e2d5b_row1_col0, #T_e2d5b_row1_col1, #T_e2d5b_row2_col0, #T_e2d5b_row2_col1, #T_e2d5b_row3_col0, #T_e2d5b_row3_col1, #T_e2d5b_row4_col0, #T_e2d5b_row4_col1, #T_e2d5b_row5_col0, #T_e2d5b_row5_col1, #T_e2d5b_row6_col0, #T_e2d5b_row6_col1, #T_e2d5b_row7_col0, #T_e2d5b_row7_col1, #T_e2d5b_row8_col0, #T_e2d5b_row8_col1, #T_e2d5b_row9_col0, #T_e2d5b_row9_col1, #T_e2d5b_row10_col0, #T_e2d5b_row10_col1, #T_e2d5b_row11_col0, #T_e2d5b_row11_col1, #T_e2d5b_row12_col0, #T_e2d5b_row12_col1, #T_e2d5b_row13_col0, #T_e2d5b_row13_col1, #T_e2d5b_row14_col0, #T_e2d5b_row14_col1, #T_e2d5b_row15_col0, #T_e2d5b_row15_col1, #T_e2d5b_row16_col0, #T_e2d5b_row16_col1, #T_e2d5b_row17_col0, #T_e2d5b_row17_col1, #T_e2d5b_row18_col0, #T_e2d5b_row18_col1, #T_e2d5b_row19_col0, #T_e2d5b_row19_col1, #T_e2d5b_row20_col0, #T_e2d5b_row20_col1, #T_e2d5b_row21_col0, #T_e2d5b_row21_col1, #T_e2d5b_row22_col0, #T_e2d5b_row22_col1, #T_e2d5b_row23_col0, #T_e2d5b_row23_col1, #T_e2d5b_row24_col0, #T_e2d5b_row24_col1, #T_e2d5b_row25_col1, #T_e2d5b_row26_col0, #T_e2d5b_row26_col1, #T_e2d5b_row27_col1, #T_e2d5b_row28_col0, #T_e2d5b_row30_col1, #T_e2d5b_row31_col0, #T_e2d5b_row34_col0, #T_e2d5b_row50_col1, #T_e2d5b_row51_col0, #T_e2d5b_row51_col1, #T_e2d5b_row52_col0, #T_e2d5b_row52_col1, #T_e2d5b_row53_col0, #T_e2d5b_row53_col1, #T_e2d5b_row54_col0, #T_e2d5b_row54_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_e2d5b_row25_col0, #T_e2d5b_row27_col0, #T_e2d5b_row28_col1, #T_e2d5b_row29_col0, #T_e2d5b_row29_col1, #T_e2d5b_row49_col0, #T_e2d5b_row49_col1 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_e2d5b_row30_col0, #T_e2d5b_row31_col1, #T_e2d5b_row33_col0, #T_e2d5b_row35_col0, #T_e2d5b_row35_col1, #T_e2d5b_row36_col0, #T_e2d5b_row36_col1, #T_e2d5b_row50_col0 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_e2d5b_row32_col0 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_e2d5b_row32_col1, #T_e2d5b_row33_col1 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_e2d5b_row34_col1, #T_e2d5b_row37_col1 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_e2d5b_row37_col0, #T_e2d5b_row46_col1, #T_e2d5b_row48_col0, #T_e2d5b_row48_col1 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_e2d5b_row38_col0 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_e2d5b_row38_col1, #T_e2d5b_row40_col1, #T_e2d5b_row41_col0, #T_e2d5b_row42_col1 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_e2d5b_row39_col0, #T_e2d5b_row39_col1 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_e2d5b_row40_col0 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_e2d5b_row41_col1, #T_e2d5b_row44_col1, #T_e2d5b_row45_col0, #T_e2d5b_row47_col1 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_e2d5b_row42_col0 {
#   background-color: #4e9ac6;
#   color: #f1f1f1;
# }
# #T_e2d5b_row43_col0, #T_e2d5b_row45_col1 {
#   background-color: #2a88bc;
#   color: #f1f1f1;
# }
# #T_e2d5b_row43_col1 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_e2d5b_row44_col0 {
#   background-color: #3b92c1;
#   color: #f1f1f1;
# }
# #T_e2d5b_row47_col0 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e2d5b_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >GÉNERO</th>
#       <th class="col_heading level0 col0" >Femenino</th>
#       <th class="col_heading level0 col1" >Masculino</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >PUNTAJE_FINAL</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e2d5b_level0_row0" class="row_heading level0 row0" >[0.0, 0.1)</th>
#       <td id="T_e2d5b_row0_col0" class="data row0 col0" >19</td>
#       <td id="T_e2d5b_row0_col1" class="data row0 col1" >26</td>
#     </tr>
#     <tr>
#       <th id="T_e2d5b_level0_row1" class="row_heading level0 row1" >[0.1, 0.2)</th>
#       <td id="T_e2d5b_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_e2d5b_row1_col1" class="data row1 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e2d5b_level0_row2" class="row_heading level0 row2" >[0.2, 0.3)</th>
#       <td id="T_e2d5b_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_e2d5b_row2_col1" class="data row2 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e2d5b_level0_row3" class="row_heading level0 row3" >[0.3, 0.4)</th>
#       <td id="T_e2d5b_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_e2d5b_row3_col1" class="data row3 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e2d5b_level0_row4" class="row_heading level0 row4" >[0.4, 0.5)</th>
#       <td id="T_e2d5b_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_e2d5b_row4_col1" class="data row4 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e2d5b_level0_row5" class="row_heading level0 row5" >[0.5, 0.6)</th>
#       <td id="T_e2d5b_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_e2d5b_row5_col1" class="data row5 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e2d5b_level0_row6" class="row_heading level0 row6" >[0.6, 0.7)</th>
#       <td id="T_e2d5b_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_e2d5b_row6_col1" class="data row6 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e2d5b_level0_row7" class="row_heading level0 row7" >[0.7, 0.8)</th>
#       <td id="T_e2d5b_row7_col0" class="data row7 col0" >0</td>
#       <td id="T_e2d5b_row7_col1" class="data row7 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e2d5b_level0_row8" class="row_heading level0 row8" >[0.8, 0.9)</th>
#       <td id="T_e2d5b_row8_col0" class="data row8 col0" >0</td>
#       <td id="T_e2d5b_row8_col1" class="data row8 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e2d5b_level0_row9" class="row_heading level0 row9" >[0.9, 1.0)</th>
#       <td id="T_e2d5b_row9_col0" class="data row9 col0" >0</td>
#       <td id="T_e2d5b_row9_col1" class="data row9 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e2d5b_level0_row10" class="row_heading level0 row10" >[1.0, 1.1)</th>
#       <td id="T_e2d5b_row10_col0" class="data row10 col0" >0</td>
#       <td id="T_e2d5b_row10_col1" class="data row10 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e2d5b_level0_row11" class="row_heading level0 row11" >[1.1, 1.2)</th>
#       <td id="T_e2d5b_row11_col0" class="data row11 col0" >0</td>
#       <td id="T_e2d5b_row11_col1" class="data row11 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e2d5b_level0_row12" class="row_heading level0 row12" >[1.2, 1.3)</th>
#       <td id="T_e2d5b_row12_col0" class="data row12 col0" >0</td>
#       <td id="T_e2d5b_row12_col1" class="data row12 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e2d5b_level0_row13" class="row_heading level0 row13" >[1.3, 1.4)</th>
#       <td id="T_e2d5b_row13_col0" class="data row13 col0" >0</td>
#       <td id="T_e2d5b_row13_col1" class="data row13 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e2d5b_level0_row14" class="row_heading level0 row14" >[1.4, 1.5)</th>
#       <td id="T_e2d5b_row14_col0" class="data row14 col0" >0</td>
#       <td id="T_e2d5b_row14_col1" class="data row14 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e2d5b_level0_row15" class="row_heading level0 row15" >[1.5, 1.6)</th>
#       <td id="T_e2d5b_row15_col0" class="data row15 col0" >0</td>
#       <td id="T_e2d5b_row15_col1" class="data row15 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e2d5b_level0_row16" class="row_heading level0 row16" >[1.6, 1.7)</th>
#       <td id="T_e2d5b_row16_col0" class="data row16 col0" >0</td>
#       <td id="T_e2d5b_row16_col1" class="data row16 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e2d5b_level0_row17" class="row_heading level0 row17" >[1.7, 1.8)</th>
#       <td id="T_e2d5b_row17_col0" class="data row17 col0" >0</td>
#       <td id="T_e2d5b_row17_col1" class="data row17 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e2d5b_level0_row18" class="row_heading level0 row18" >[1.8, 1.9)</th>
#       <td i

# %%
df_doc.groupby(["GÉNERO", pd.cut(df_doc.PUNTAJE_FINAL_NP, bins, right=False, include_lowest=True)])["FOLIO"].count().unstack(0).style.background_gradient()
# Out:
# <style type="text/css">
# #T_a0bfc_row0_col0 {
#   background-color: #04629a;
#   color: #f1f1f1;
# }
# #T_a0bfc_row0_col1, #T_a0bfc_row46_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_a0bfc_row1_col0, #T_a0bfc_row1_col1, #T_a0bfc_row2_col0, #T_a0bfc_row2_col1, #T_a0bfc_row3_col0, #T_a0bfc_row3_col1, #T_a0bfc_row4_col0, #T_a0bfc_row4_col1, #T_a0bfc_row5_col0, #T_a0bfc_row5_col1, #T_a0bfc_row6_col0, #T_a0bfc_row6_col1, #T_a0bfc_row7_col0, #T_a0bfc_row7_col1, #T_a0bfc_row8_col0, #T_a0bfc_row8_col1, #T_a0bfc_row9_col0, #T_a0bfc_row9_col1, #T_a0bfc_row10_col0, #T_a0bfc_row10_col1, #T_a0bfc_row11_col0, #T_a0bfc_row11_col1, #T_a0bfc_row12_col0, #T_a0bfc_row12_col1, #T_a0bfc_row13_col0, #T_a0bfc_row13_col1, #T_a0bfc_row14_col0, #T_a0bfc_row14_col1, #T_a0bfc_row15_col0, #T_a0bfc_row15_col1, #T_a0bfc_row16_col0, #T_a0bfc_row16_col1, #T_a0bfc_row17_col0, #T_a0bfc_row17_col1, #T_a0bfc_row18_col0, #T_a0bfc_row18_col1, #T_a0bfc_row19_col0, #T_a0bfc_row19_col1, #T_a0bfc_row20_col0, #T_a0bfc_row20_col1, #T_a0bfc_row21_col0, #T_a0bfc_row21_col1, #T_a0bfc_row22_col0, #T_a0bfc_row22_col1, #T_a0bfc_row23_col0, #T_a0bfc_row23_col1, #T_a0bfc_row24_col0, #T_a0bfc_row24_col1, #T_a0bfc_row25_col1, #T_a0bfc_row26_col0, #T_a0bfc_row26_col1, #T_a0bfc_row27_col0, #T_a0bfc_row27_col1, #T_a0bfc_row29_col1, #T_a0bfc_row32_col0, #T_a0bfc_row50_col1, #T_a0bfc_row51_col0, #T_a0bfc_row51_col1, #T_a0bfc_row52_col0, #T_a0bfc_row52_col1, #T_a0bfc_row53_col0, #T_a0bfc_row53_col1, #T_a0bfc_row54_col0, #T_a0bfc_row54_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_a0bfc_row25_col0, #T_a0bfc_row28_col0, #T_a0bfc_row30_col0, #T_a0bfc_row31_col0, #T_a0bfc_row35_col0 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_a0bfc_row28_col1, #T_a0bfc_row31_col1 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_a0bfc_row29_col0, #T_a0bfc_row33_col0, #T_a0bfc_row36_col0, #T_a0bfc_row50_col0 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_a0bfc_row30_col1, #T_a0bfc_row36_col1, #T_a0bfc_row49_col1 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_a0bfc_row32_col1 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_a0bfc_row33_col1, #T_a0bfc_row35_col1 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_a0bfc_row34_col0, #T_a0bfc_row49_col0 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_a0bfc_row34_col1 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_a0bfc_row37_col0, #T_a0bfc_row48_col0 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_a0bfc_row37_col1, #T_a0bfc_row39_col1, #T_a0bfc_row42_col1, #T_a0bfc_row48_col1 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_a0bfc_row38_col0 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_a0bfc_row38_col1 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_a0bfc_row39_col0 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_a0bfc_row40_col0, #T_a0bfc_row44_col0 {
#   background-color: #2c89bd;
#   color: #f1f1f1;
# }
# #T_a0bfc_row40_col1 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_a0bfc_row41_col0 {
#   background-color: #8eb3d5;
#   color: #000000;
# }
# #T_a0bfc_row41_col1 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_a0bfc_row42_col0 {
#   background-color: #197db7;
#   color: #f1f1f1;
# }
# #T_a0bfc_row43_col0, #T_a0bfc_row45_col0 {
#   background-color: #549cc7;
#   color: #f1f1f1;
# }
# #T_a0bfc_row43_col1 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_a0bfc_row44_col1 {
#   background-color: #3b92c1;
#   color: #f1f1f1;
# }
# #T_a0bfc_row45_col1 {
#   background-color: #4e9ac6;
#   color: #f1f1f1;
# }
# #T_a0bfc_row46_col1, #T_a0bfc_row47_col1 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_a0bfc_row47_col0 {
#   background-color: #0872b1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a0bfc_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >GÉNERO</th>
#       <th class="col_heading level0 col0" >Femenino</th>
#       <th class="col_heading level0 col1" >Masculino</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >PUNTAJE_FINAL_NP</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a0bfc_level0_row0" class="row_heading level0 row0" >[0.0, 0.1)</th>
#       <td id="T_a0bfc_row0_col0" class="data row0 col0" >19</td>
#       <td id="T_a0bfc_row0_col1" class="data row0 col1" >26</td>
#     </tr>
#     <tr>
#       <th id="T_a0bfc_level0_row1" class="row_heading level0 row1" >[0.1, 0.2)</th>
#       <td id="T_a0bfc_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_a0bfc_row1_col1" class="data row1 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_a0bfc_level0_row2" class="row_heading level0 row2" >[0.2, 0.3)</th>
#       <td id="T_a0bfc_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_a0bfc_row2_col1" class="data row2 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_a0bfc_level0_row3" class="row_heading level0 row3" >[0.3, 0.4)</th>
#       <td id="T_a0bfc_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_a0bfc_row3_col1" class="data row3 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_a0bfc_level0_row4" class="row_heading level0 row4" >[0.4, 0.5)</th>
#       <td id="T_a0bfc_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_a0bfc_row4_col1" class="data row4 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_a0bfc_level0_row5" class="row_heading level0 row5" >[0.5, 0.6)</th>
#       <td id="T_a0bfc_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_a0bfc_row5_col1" class="data row5 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_a0bfc_level0_row6" class="row_heading level0 row6" >[0.6, 0.7)</th>
#       <td id="T_a0bfc_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_a0bfc_row6_col1" class="data row6 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_a0bfc_level0_row7" class="row_heading level0 row7" >[0.7, 0.8)</th>
#       <td id="T_a0bfc_row7_col0" class="data row7 col0" >0</td>
#       <td id="T_a0bfc_row7_col1" class="data row7 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_a0bfc_level0_row8" class="row_heading level0 row8" >[0.8, 0.9)</th>
#       <td id="T_a0bfc_row8_col0" class="data row8 col0" >0</td>
#       <td id="T_a0bfc_row8_col1" class="data row8 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_a0bfc_level0_row9" class="row_heading level0 row9" >[0.9, 1.0)</th>
#       <td id="T_a0bfc_row9_col0" class="data row9 col0" >0</td>
#       <td id="T_a0bfc_row9_col1" class="data row9 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_a0bfc_level0_row10" class="row_heading level0 row10" >[1.0, 1.1)</th>
#       <td id="T_a0bfc_row10_col0" class="data row10 col0" >0</td>
#       <td id="T_a0bfc_row10_col1" class="data row10 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_a0bfc_level0_row11" class="row_heading level0 row11" >[1.1, 1.2)</th>
#       <td id="T_a0bfc_row11_col0" class="data row11 col0" >0</td>
#       <td id="T_a0bfc_row11_col1" class="data row11 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_a0bfc_level0_row12" class="row_heading level0 row12" >[1.2, 1.3)</th>
#       <td id="T_a0bfc_row12_col0" class="data row12 col0" >0</td>
#       <td id="T_a0bfc_row12_col1" class="data row12 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_a0bfc_level0_row13" class="row_heading level0 row13" >[1.3, 1.4)</th>
#       <td id="T_a0bfc_row13_col0" class="data row13 col0" >0</td>
#       <td id="T_a0bfc_row13_col1" class="data row13 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_a0bfc_level0_row14" class="row_heading level0 row14" >[1.4, 1.5)</th>
#       <td id="T_a0bfc_row14_col0" class="data row14 col0" >0</td>
#       <td id="T_a0bfc_row14_col1" class="data row14 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_a0bfc_level0_row15" class="row_heading level0 row15" >[1.5, 1.6)</th>
#       <td id="T_a0bfc_row15_col0" class="data row15 col0" >0</td>
#       <td id="T_a0bfc_row15_col1" class="data row15 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_a0bfc_level0_row16" class="row_heading level0 row16" >[1.6, 1.7)</th>
#       <td id="T_a0bfc_row16_col0" class="data row16 col0" >0</td>
#       <td id="T_

# %%
df_doc[df_doc['ESTADO_FINAL'] == 'SELECCIONADA'].groupby(['COMITÉ', 'GÉNERO'])['FOLIO'].count().sort_values().unstack(1).fillna(0).astype('int').style.background_gradient(cmap= 'YlOrRd')
# Out:
# <style type="text/css">
# #T_bfd48_row0_col0, #T_bfd48_row1_col0, #T_bfd48_row5_col0, #T_bfd48_row7_col0, #T_bfd48_row12_col0, #T_bfd48_row14_col0, #T_bfd48_row23_col0 {
#   background-color: #fff9be;
#   color: #000000;
# }
# #T_bfd48_row0_col1, #T_bfd48_row12_col1, #T_bfd48_row27_col0 {
#   background-color: #fed976;
#   color: #000000;
# }
# #T_bfd48_row1_col1, #T_bfd48_row2_col1, #T_bfd48_row4_col0, #T_bfd48_row6_col1, #T_bfd48_row8_col0, #T_bfd48_row14_col1, #T_bfd48_row25_col1 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_bfd48_row2_col0, #T_bfd48_row10_col0, #T_bfd48_row16_col0, #T_bfd48_row21_col0 {
#   background-color: #ffeda0;
#   color: #000000;
# }
# #T_bfd48_row3_col0, #T_bfd48_row4_col1, #T_bfd48_row5_col1, #T_bfd48_row6_col0, #T_bfd48_row7_col1, #T_bfd48_row11_col0, #T_bfd48_row19_col0, #T_bfd48_row20_col0, #T_bfd48_row20_col1 {
#   background-color: #fff3af;
#   color: #000000;
# }
# #T_bfd48_row3_col1, #T_bfd48_row15_col0, #T_bfd48_row21_col1, #T_bfd48_row24_col1, #T_bfd48_row26_col1, #T_bfd48_row27_col1 {
#   background-color: #ffe793;
#   color: #000000;
# }
# #T_bfd48_row8_col1, #T_bfd48_row10_col1, #T_bfd48_row11_col1, #T_bfd48_row13_col0, #T_bfd48_row15_col1, #T_bfd48_row16_col1, #T_bfd48_row19_col1, #T_bfd48_row22_col0 {
#   background-color: #febf5a;
#   color: #000000;
# }
# #T_bfd48_row9_col0 {
#   background-color: #fecc68;
#   color: #000000;
# }
# #T_bfd48_row9_col1 {
#   background-color: #fd8c3c;
#   color: #f1f1f1;
# }
# #T_bfd48_row13_col1, #T_bfd48_row17_col0 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_bfd48_row17_col1 {
#   background-color: #f43d25;
#   color: #f1f1f1;
# }
# #T_bfd48_row18_col0, #T_bfd48_row18_col1, #T_bfd48_row22_col1, #T_bfd48_row23_col1 {
#   background-color: #fea647;
#   color: #000000;
# }
# #T_bfd48_row24_col0 {
#   background-color: #fee084;
#   color: #000000;
# }
# #T_bfd48_row25_col0 {
#   background-color: #feb24c;
#   color: #000000;
# }
# #T_bfd48_row26_col0 {
#   background-color: #fd9941;
#   color: #000000;
# }
# </style>
# <table id="T_bfd48_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >GÉNERO</th>
#       <th class="col_heading level0 col0" >Femenino</th>
#       <th class="col_heading level0 col1" >Masculino</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >COMITÉ</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bfd48_level0_row0" class="row_heading level0 row0" >Administración</th>
#       <td id="T_bfd48_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_bfd48_row0_col1" class="data row0 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_bfd48_level0_row1" class="row_heading level0 row1" >Agronomía y Forestal</th>
#       <td id="T_bfd48_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_bfd48_row1_col1" class="data row1 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_bfd48_level0_row2" class="row_heading level0 row2" >Arquitectura</th>
#       <td id="T_bfd48_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_bfd48_row2_col1" class="data row2 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_bfd48_level0_row3" class="row_heading level0 row3" >Arte</th>
#       <td id="T_bfd48_row3_col0" class="data row3 col0" >2</td>
#       <td id="T_bfd48_row3_col1" class="data row3 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_bfd48_level0_row4" class="row_heading level0 row4" >Biología Celular y Molecular</th>
#       <td id="T_bfd48_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_bfd48_row4_col1" class="data row4 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_bfd48_level0_row5" class="row_heading level0 row5" >Biología Fisiológica y Bioquímica</th>
#       <td id="T_bfd48_row5_col0" class="data row5 col0" >1</td>
#       <td id="T_bfd48_row5_col1" class="data row5 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_bfd48_level0_row6" class="row_heading level0 row6" >Biotecnología</th>
#       <td id="T_bfd48_row6_col0" class="data row6 col0" >2</td>
#       <td id="T_bfd48_row6_col1" class="data row6 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_bfd48_level0_row7" class="row_heading level0 row7" >Computación e Informática</th>
#       <td id="T_bfd48_row7_col0" class="data row7 col0" >1</td>
#       <td id="T_bfd48_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_bfd48_level0_row8" class="row_heading level0 row8" >Cs. Matemáticas</th>
#       <td id="T_bfd48_row8_col0" class="data row8 col0" >0</td>
#       <td id="T_bfd48_row8_col1" class="data row8 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_bfd48_level0_row9" class="row_heading level0 row9" >Cs. Médicas</th>
#       <td id="T_bfd48_row9_col0" class="data row9 col0" >7</td>
#       <td id="T_bfd48_row9_col1" class="data row9 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_bfd48_level0_row10" class="row_heading level0 row10" >Cs. Políticas y Estudios Internacionales</th>
#       <td id="T_bfd48_row10_col0" class="data row10 col0" >3</td>
#       <td id="T_bfd48_row10_col1" class="data row10 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_bfd48_level0_row11" class="row_heading level0 row11" >Cs. de la Ingeniería I</th>
#       <td id="T_bfd48_row11_col0" class="data row11 col0" >2</td>
#       <td id="T_bfd48_row11_col1" class="data row11 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_bfd48_level0_row12" class="row_heading level0 row12" >Cs. de la Ingeniería II</th>
#       <td id="T_bfd48_row12_col0" class="data row12 col0" >1</td>
#       <td id="T_bfd48_row12_col1" class="data row12 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_bfd48_level0_row13" class="row_heading level0 row13" >Derecho</th>
#       <td id="T_bfd48_row13_col0" class="data row13 col0" >8</td>
#       <td id="T_bfd48_row13_col1" class="data row13 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_bfd48_level0_row14" class="row_heading level0 row14" >Diseño</th>
#       <td id="T_bfd48_row14_col0" class="data row14 col0" >1</td>
#       <td id="T_bfd48_row14_col1" class="data row14 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_bfd48_level0_row15" class="row_heading level0 row15" >Ecología y Ciencias Naturales</th>
#       <td id="T_bfd48_row15_col0" class="data row15 col0" >4</td>
#       <td id="T_bfd48_row15_col1" class="data row15 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_bfd48_level0_row16" class="row_heading level0 row16" >Economía</th>
#       <td id="T_bfd48_row16_col0" class="data row16 col0" >3</td>
#       <td id="T_bfd48_row16_col1" class="data row16 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_bfd48_level0_row17" class="row_heading level0 row17" >Educación I</th>
#       <td id="T_bfd48_row17_col0" class="data row17 col0" >24</td>
#       <td id="T_bfd48_row17_col1" class="data row17 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_bfd48_level0_row18" class="row_heading level0 row18" >Educación II</th>
#       <td id="T_bfd48_row18_col0" class="data row18 col0" >10</td>
#       <td id="T_bfd48_row18_col1" class="data row18 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_bfd48_level0_row19" class="row_heading level0 row19" >Filosofía</th>
#       <td id="T_bfd48_row19_col0" class="data row19 col0" >2</td>
#       <td id="T_bfd48_row19_col1" class="data row19 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_bfd48_level0_row20" class="row_heading level0 row20" >Física y Astronomía</th>
#       <td id="T_bfd48_row20_col0" class="data row20 col0" >2</td>
#       <td id="T_bfd48_row20_col1" class="data row20 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_bfd48_level0_row21" class="row_heading level0 row21" >Geología y Oceanografía</th>
#       <td id="T_bfd48_row21_col0" class="data row21 col0" >3</td>
#       <td id="T_bfd48_row21_col1" class="data row21 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_bfd48_level0_row22" class="row_heading level0 row22" >Historia, Antropología y Arqueología</th>
#       <td id="T_bfd48_row22_col0" class="data row22 col0" >8</td>
#       <td id="T_bfd48_row22_col1" class="data row22 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_bfd48_level0_row23" class="row_heading level0

# %%
brecha = df_doc[df_doc['ESTADO_FINAL'] == 'SELECCIONADA'].groupby(['COMITÉ'])['GÉNERO'].value_counts("%").sort_values().unstack(1).fillna(0)

brecha['Brecha'] =  brecha['Masculino'] - brecha['Femenino']

brecha = brecha*100

brecha.style.background_gradient(cmap= 'YlOrRd', subset=['Brecha'])
# Out:
# <style type="text/css">
# #T_98a5f_row0_col2, #T_98a5f_row12_col2 {
#   background-color: #e2191c;
#   color: #f1f1f1;
# }
# #T_98a5f_row1_col2, #T_98a5f_row2_col2, #T_98a5f_row6_col2, #T_98a5f_row14_col2, #T_98a5f_row25_col2 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_98a5f_row3_col2, #T_98a5f_row5_col2, #T_98a5f_row7_col2, #T_98a5f_row15_col2 {
#   background-color: #fd8c3c;
#   color: #f1f1f1;
# }
# #T_98a5f_row4_col2, #T_98a5f_row8_col2 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_98a5f_row9_col2 {
#   background-color: #fd9841;
#   color: #000000;
# }
# #T_98a5f_row10_col2, #T_98a5f_row16_col2 {
#   background-color: #fc6832;
#   color: #f1f1f1;
# }
# #T_98a5f_row11_col2, #T_98a5f_row19_col2 {
#   background-color: #f43d25;
#   color: #f1f1f1;
# }
# #T_98a5f_row13_col2 {
#   background-color: #fc5b2e;
#   color: #f1f1f1;
# }
# #T_98a5f_row17_col2, #T_98a5f_row27_col2 {
#   background-color: #fed976;
#   color: #000000;
# }
# #T_98a5f_row18_col2, #T_98a5f_row20_col2 {
#   background-color: #febf5a;
#   color: #000000;
# }
# #T_98a5f_row21_col2 {
#   background-color: #feab49;
#   color: #000000;
# }
# #T_98a5f_row22_col2 {
#   background-color: #feaf4b;
#   color: #000000;
# }
# #T_98a5f_row23_col2 {
#   background-color: #c90823;
#   color: #f1f1f1;
# }
# #T_98a5f_row24_col2 {
#   background-color: #fece6a;
#   color: #000000;
# }
# #T_98a5f_row26_col2 {
#   background-color: #ffe997;
#   color: #000000;
# }
# </style>
# <table id="T_98a5f_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >GÉNERO</th>
#       <th class="col_heading level0 col0" >Femenino</th>
#       <th class="col_heading level0 col1" >Masculino</th>
#       <th class="col_heading level0 col2" >Brecha</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >COMITÉ</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_98a5f_level0_row0" class="row_heading level0 row0" >Administración</th>
#       <td id="T_98a5f_row0_col0" class="data row0 col0" >25.000</td>
#       <td id="T_98a5f_row0_col1" class="data row0 col1" >75.000</td>
#       <td id="T_98a5f_row0_col2" class="data row0 col2" >50.000</td>
#     </tr>
#     <tr>
#       <th id="T_98a5f_level0_row1" class="row_heading level0 row1" >Agronomía y Forestal</th>
#       <td id="T_98a5f_row1_col0" class="data row1 col0" >100.000</td>
#       <td id="T_98a5f_row1_col1" class="data row1 col1" >0.000</td>
#       <td id="T_98a5f_row1_col2" class="data row1 col2" >-100.000</td>
#     </tr>
#     <tr>
#       <th id="T_98a5f_level0_row2" class="row_heading level0 row2" >Arquitectura</th>
#       <td id="T_98a5f_row2_col0" class="data row2 col0" >100.000</td>
#       <td id="T_98a5f_row2_col1" class="data row2 col1" >0.000</td>
#       <td id="T_98a5f_row2_col2" class="data row2 col2" >-100.000</td>
#     </tr>
#     <tr>
#       <th id="T_98a5f_level0_row3" class="row_heading level0 row3" >Arte</th>
#       <td id="T_98a5f_row3_col0" class="data row3 col0" >50.000</td>
#       <td id="T_98a5f_row3_col1" class="data row3 col1" >50.000</td>
#       <td id="T_98a5f_row3_col2" class="data row3 col2" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_98a5f_level0_row4" class="row_heading level0 row4" >Biología Celular y Molecular</th>
#       <td id="T_98a5f_row4_col0" class="data row4 col0" >0.000</td>
#       <td id="T_98a5f_row4_col1" class="data row4 col1" >100.000</td>
#       <td id="T_98a5f_row4_col2" class="data row4 col2" >100.000</td>
#     </tr>
#     <tr>
#       <th id="T_98a5f_level0_row5" class="row_heading level0 row5" >Biología Fisiológica y Bioquímica</th>
#       <td id="T_98a5f_row5_col0" class="data row5 col0" >50.000</td>
#       <td id="T_98a5f_row5_col1" class="data row5 col1" >50.000</td>
#       <td id="T_98a5f_row5_col2" class="data row5 col2" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_98a5f_level0_row6" class="row_heading level0 row6" >Biotecnología</th>
#       <td id="T_98a5f_row6_col0" class="data row6 col0" >100.000</td>
#       <td id="T_98a5f_row6_col1" class="data row6 col1" >0.000</td>
#       <td id="T_98a5f_row6_col2" class="data row6 col2" >-100.000</td>
#     </tr>
#     <tr>
#       <th id="T_98a5f_level0_row7" class="row_heading level0 row7" >Computación e Informática</th>
#       <td id="T_98a5f_row7_col0" class="data row7 col0" >50.000</td>
#       <td id="T_98a5f_row7_col1" class="data row7 col1" >50.000</td>
#       <td id="T_98a5f_row7_col2" class="data row7 col2" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_98a5f_level0_row8" class="row_heading level0 row8" >Cs. Matemáticas</th>
#       <td id="T_98a5f_row8_col0" class="data row8 col0" >0.000</td>
#       <td id="T_98a5f_row8_col1" class="data row8 col1" >100.000</td>
#       <td id="T_98a5f_row8_col2" class="data row8 col2" >100.000</td>
#     </tr>
#     <tr>
#       <th id="T_98a5f_level0_row9" class="row_heading level0 row9" >Cs. Médicas</th>
#       <td id="T_98a5f_row9_col0" class="data row9 col0" >53.846</td>
#       <td id="T_98a5f_row9_col1" class="data row9 col1" >46.154</td>
#       <td id="T_98a5f_row9_col2" class="data row9 col2" >-7.692</td>
#     </tr>
#     <tr>
#       <th id="T_98a5f_level0_row10" class="row_heading level0 row10" >Cs. Políticas y Estudios Internacionales</th>
#       <td id="T_98a5f_row10_col0" class="data row10 col0" >42.857</td>
#       <td id="T_98a5f_row10_col1" class="data row10 col1" >57.143</td>
#       <td id="T_98a5f_row10_col2" class="data row10 col2" >14.286</td>
#     </tr>
#     <tr>
#       <th id="T_98a5f_level0_row11" class="row_heading level0 row11" >Cs. de la Ingeniería I</th>
#       <td id="T_98a5f_row11_col0" class="data row11 col0" >33.333</td>
#       <td id="T_98a5f_row11_col1" class="data row11 col1" >66.667</td>
#       <td id="T_98a5f_row11_col2" class="data row11 col2" >33.333</td>
#     </tr>
#     <tr>
#       <th id="T_98a5f_level0_row12" class="row_heading level0 row12" >Cs. de la Ingeniería II</th>
#       <td id="T_98a5f_row12_col0" class="data row12 col0" >25.000</td>
#       <td id="T_98a5f_row12_col1" class="data row12 col1" >75.000</td>
#       <td id="T_98a5f_row12_col2" class="data row12 col2" >50.000</td>
#     </tr>
#     <tr>
#       <th id="T_98a5f_level0_row13" class="row_heading level0 row13" >Derecho</th>
#       <td id="T_98a5f_row13_col0" class="data row13 col0" >40.000</td>
#       <td id="T_98a5f_row13_col1" class="data row13 col1" >60.000</td>
#       <td id="T_98a5f_row13_col2" class="data row13 col2" >20.000</td>
#     </tr>
#     <tr>
#       <th id="T_98a5f_level0_row14" class="row_heading level0 row14" >Diseño</th>
#       <td id="T_98a5f_row14_col0" class="data row14 col0" >100.000</td>
#       <td id="T_98a5f_row14_col1" class="data row14 col1" >0.000</td>
#       <td id="T_98a5f_row14_col2" class="data row14 col2" >-100.000</td>
#     </tr>
#     <tr>
#       <th id="T_98a5f_level0_row15" class="row_heading level0 row15" >Ecología y Ciencias Naturales</th>
#       <td id="T_98a5f_row15_col0" class="data row15 col0" >50.000</td>
#       <td id="T_98a5f_row15_col1" class="data row15 col1" >50.000</td>
#       <td id="T_98a5f_row15_col2" class="data row15 col2" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_98a5f_level0_row16" class="row_heading level0 row16" >Economía</th>
#       <td id="T_98a5f_row16_col0" class="data row16 col0" >42.857</td>
#       <td id="T_98a5f_row16_col1" class="data row16 col1" >57.143</td>
#       <td id="T_98a5f_row16_col2" class="data row16 col2" >14.286</td>
#     </tr>
#     <tr>
#       <th id="T_98a5f_level0_row17" class="row_heading level0 row17" >Educación I</th>
#       <td id="T_98a5f_row17_col0" class="data row17 col0" >75.000</td>
#       <td id="T_98a5f_row17_col1" class="data row17 col1" >25.000</td>
#       <td id="T_98a5f_row17_col2" class="data row17 col2" >-50.000</td>
#     </tr>
#     <tr>
#       <th id="T_98a5f_level0_row18" class="row_heading level0 row18" >Educación II</th>
#       <td id="T_98a5f_row18_col0" class="data row18 col0" >66.667</td>
#       <td id="T_98a5f_row18_col1" class="data row18 col1" >33.333</td>
#       <td id="T_98a5f_row18_col2" class="data row18 col2" >-33.333</td>
#     </tr>
#     <tr>
#       <th id="

# %%
df_doc[df_doc['ESTADO_FINAL_NP'] == 'SELECCIONADA'].groupby(['COMITÉ', 'GÉNERO'])['FOLIO'].count().sort_values().unstack(1).fillna(0).astype('int').style.background_gradient(cmap= 'YlOrRd')
# Out:
# <style type="text/css">
# #T_91bb4_row0_col0, #T_91bb4_row1_col0, #T_91bb4_row5_col0, #T_91bb4_row7_col0, #T_91bb4_row12_col0, #T_91bb4_row14_col0, #T_91bb4_row23_col0 {
#   background-color: #fff9be;
#   color: #000000;
# }
# #T_91bb4_row0_col1, #T_91bb4_row22_col1, #T_91bb4_row23_col1 {
#   background-color: #feaf4b;
#   color: #000000;
# }
# #T_91bb4_row1_col1, #T_91bb4_row2_col1, #T_91bb4_row4_col0, #T_91bb4_row8_col0, #T_91bb4_row14_col1, #T_91bb4_row25_col1 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_91bb4_row2_col0, #T_91bb4_row3_col0, #T_91bb4_row6_col0, #T_91bb4_row11_col0, #T_91bb4_row19_col0, #T_91bb4_row20_col0, #T_91bb4_row21_col0 {
#   background-color: #fff3af;
#   color: #000000;
# }
# #T_91bb4_row3_col1, #T_91bb4_row21_col1, #T_91bb4_row24_col1, #T_91bb4_row26_col1 {
#   background-color: #ffe997;
#   color: #000000;
# }
# #T_91bb4_row4_col1, #T_91bb4_row5_col1, #T_91bb4_row6_col1, #T_91bb4_row7_col1, #T_91bb4_row20_col1 {
#   background-color: #fff4b2;
#   color: #000000;
# }
# #T_91bb4_row8_col1, #T_91bb4_row10_col1, #T_91bb4_row11_col1, #T_91bb4_row15_col1, #T_91bb4_row16_col1, #T_91bb4_row19_col1 {
#   background-color: #fec863;
#   color: #000000;
# }
# #T_91bb4_row9_col0, #T_91bb4_row13_col0 {
#   background-color: #fecc68;
#   color: #000000;
# }
# #T_91bb4_row9_col1, #T_91bb4_row18_col1 {
#   background-color: #fd9841;
#   color: #000000;
# }
# #T_91bb4_row10_col0 {
#   background-color: #ffeda0;
#   color: #000000;
# }
# #T_91bb4_row12_col1, #T_91bb4_row27_col1 {
#   background-color: #fedc7c;
#   color: #000000;
# }
# #T_91bb4_row13_col1, #T_91bb4_row17_col0 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_91bb4_row15_col0, #T_91bb4_row16_col0 {
#   background-color: #ffe793;
#   color: #000000;
# }
# #T_91bb4_row17_col1 {
#   background-color: #fc532b;
#   color: #f1f1f1;
# }
# #T_91bb4_row18_col0, #T_91bb4_row26_col0 {
#   background-color: #fd9941;
#   color: #000000;
# }
# #T_91bb4_row22_col0 {
#   background-color: #febf5a;
#   color: #000000;
# }
# #T_91bb4_row24_col0 {
#   background-color: #fee084;
#   color: #000000;
# }
# #T_91bb4_row25_col0 {
#   background-color: #feb24c;
#   color: #000000;
# }
# #T_91bb4_row27_col0 {
#   background-color: #fed976;
#   color: #000000;
# }
# </style>
# <table id="T_91bb4_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >GÉNERO</th>
#       <th class="col_heading level0 col0" >Femenino</th>
#       <th class="col_heading level0 col1" >Masculino</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >COMITÉ</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_91bb4_level0_row0" class="row_heading level0 row0" >Administración</th>
#       <td id="T_91bb4_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_91bb4_row0_col1" class="data row0 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_91bb4_level0_row1" class="row_heading level0 row1" >Agronomía y Forestal</th>
#       <td id="T_91bb4_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_91bb4_row1_col1" class="data row1 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_91bb4_level0_row2" class="row_heading level0 row2" >Arquitectura</th>
#       <td id="T_91bb4_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_91bb4_row2_col1" class="data row2 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_91bb4_level0_row3" class="row_heading level0 row3" >Arte</th>
#       <td id="T_91bb4_row3_col0" class="data row3 col0" >2</td>
#       <td id="T_91bb4_row3_col1" class="data row3 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_91bb4_level0_row4" class="row_heading level0 row4" >Biología Celular y Molecular</th>
#       <td id="T_91bb4_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_91bb4_row4_col1" class="data row4 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_91bb4_level0_row5" class="row_heading level0 row5" >Biología Fisiológica y Bioquímica</th>
#       <td id="T_91bb4_row5_col0" class="data row5 col0" >1</td>
#       <td id="T_91bb4_row5_col1" class="data row5 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_91bb4_level0_row6" class="row_heading level0 row6" >Biotecnología</th>
#       <td id="T_91bb4_row6_col0" class="data row6 col0" >2</td>
#       <td id="T_91bb4_row6_col1" class="data row6 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_91bb4_level0_row7" class="row_heading level0 row7" >Computación e Informática</th>
#       <td id="T_91bb4_row7_col0" class="data row7 col0" >1</td>
#       <td id="T_91bb4_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_91bb4_level0_row8" class="row_heading level0 row8" >Cs. Matemáticas</th>
#       <td id="T_91bb4_row8_col0" class="data row8 col0" >0</td>
#       <td id="T_91bb4_row8_col1" class="data row8 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_91bb4_level0_row9" class="row_heading level0 row9" >Cs. Médicas</th>
#       <td id="T_91bb4_row9_col0" class="data row9 col0" >7</td>
#       <td id="T_91bb4_row9_col1" class="data row9 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_91bb4_level0_row10" class="row_heading level0 row10" >Cs. Políticas y Estudios Internacionales</th>
#       <td id="T_91bb4_row10_col0" class="data row10 col0" >3</td>
#       <td id="T_91bb4_row10_col1" class="data row10 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_91bb4_level0_row11" class="row_heading level0 row11" >Cs. de la Ingeniería I</th>
#       <td id="T_91bb4_row11_col0" class="data row11 col0" >2</td>
#       <td id="T_91bb4_row11_col1" class="data row11 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_91bb4_level0_row12" class="row_heading level0 row12" >Cs. de la Ingeniería II</th>
#       <td id="T_91bb4_row12_col0" class="data row12 col0" >1</td>
#       <td id="T_91bb4_row12_col1" class="data row12 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_91bb4_level0_row13" class="row_heading level0 row13" >Derecho</th>
#       <td id="T_91bb4_row13_col0" class="data row13 col0" >7</td>
#       <td id="T_91bb4_row13_col1" class="data row13 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_91bb4_level0_row14" class="row_heading level0 row14" >Diseño</th>
#       <td id="T_91bb4_row14_col0" class="data row14 col0" >1</td>
#       <td id="T_91bb4_row14_col1" class="data row14 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_91bb4_level0_row15" class="row_heading level0 row15" >Ecología y Ciencias Naturales</th>
#       <td id="T_91bb4_row15_col0" class="data row15 col0" >4</td>
#       <td id="T_91bb4_row15_col1" class="data row15 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_91bb4_level0_row16" class="row_heading level0 row16" >Economía</th>
#       <td id="T_91bb4_row16_col0" class="data row16 col0" >4</td>
#       <td id="T_91bb4_row16_col1" class="data row16 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_91bb4_level0_row17" class="row_heading level0 row17" >Educación I</th>
#       <td id="T_91bb4_row17_col0" class="data row17 col0" >24</td>
#       <td id="T_91bb4_row17_col1" class="data row17 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_91bb4_level0_row18" class="row_heading level0 row18" >Educación II</th>
#       <td id="T_91bb4_row18_col0" class="data row18 col0" >11</td>
#       <td id="T_91bb4_row18_col1" class="data row18 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_91bb4_level0_row19" class="row_heading level0 row19" >Filosofía</th>
#       <td id="T_91bb4_row19_col0" class="data row19 col0" >2</td>
#       <td id="T_91bb4_row19_col1" class="data row19 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_91bb4_level0_row20" class="row_heading level0 row20" >Física y Astronomía</th>
#       <td id="T_91bb4_row20_col0" class="data row20 col0" >2</td>
#       <td id="T_91bb4_row20_col1" class="data row20 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_91bb4_level0_row21" class="row_heading level0 row21" >Geología y Oceanografía</th>
#       <td id="T_91bb4_row21_col0" class="data row21 col0" >2</td>
#       <td id="T_91bb4_row21_col1" class="data row21 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_91bb4_level0_row22" class="row_heading level0 row22" >Historia, Antropología y Arqueología</th>
#       <td id=

# %%
brecha_np = df_doc[df_doc['ESTADO_FINAL_NP'] == 'SELECCIONADA'].groupby(['COMITÉ'])['GÉNERO'].value_counts("%").sort_values().unstack(1).fillna(0)

brecha_np['Brecha'] =  brecha_np['Masculino'] - brecha_np['Femenino']

brecha_np = brecha_np*100

brecha_np.style.background_gradient(cmap= 'YlOrRd', subset=['Brecha'])
# Out:
# <style type="text/css">
# #T_0a1c5_row0_col2, #T_0a1c5_row23_col2 {
#   background-color: #c90823;
#   color: #f1f1f1;
# }
# #T_0a1c5_row1_col2, #T_0a1c5_row2_col2, #T_0a1c5_row14_col2, #T_0a1c5_row25_col2 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_0a1c5_row3_col2, #T_0a1c5_row5_col2, #T_0a1c5_row7_col2, #T_0a1c5_row15_col2, #T_0a1c5_row16_col2, #T_0a1c5_row21_col2 {
#   background-color: #fd8c3c;
#   color: #f1f1f1;
# }
# #T_0a1c5_row4_col2, #T_0a1c5_row8_col2 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_0a1c5_row6_col2, #T_0a1c5_row20_col2, #T_0a1c5_row27_col2 {
#   background-color: #febf5a;
#   color: #000000;
# }
# #T_0a1c5_row9_col2 {
#   background-color: #fd9841;
#   color: #000000;
# }
# #T_0a1c5_row10_col2 {
#   background-color: #fc6832;
#   color: #f1f1f1;
# }
# #T_0a1c5_row11_col2, #T_0a1c5_row19_col2 {
#   background-color: #f43d25;
#   color: #f1f1f1;
# }
# #T_0a1c5_row12_col2 {
#   background-color: #e2191c;
#   color: #f1f1f1;
# }
# #T_0a1c5_row13_col2 {
#   background-color: #f74327;
#   color: #f1f1f1;
# }
# #T_0a1c5_row17_col2 {
#   background-color: #fed976;
#   color: #000000;
# }
# #T_0a1c5_row18_col2 {
#   background-color: #feb953;
#   color: #000000;
# }
# #T_0a1c5_row22_col2 {
#   background-color: #feaf4b;
#   color: #000000;
# }
# #T_0a1c5_row24_col2 {
#   background-color: #fece6a;
#   color: #000000;
# }
# #T_0a1c5_row26_col2 {
#   background-color: #ffe997;
#   color: #000000;
# }
# </style>
# <table id="T_0a1c5_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >GÉNERO</th>
#       <th class="col_heading level0 col0" >Femenino</th>
#       <th class="col_heading level0 col1" >Masculino</th>
#       <th class="col_heading level0 col2" >Brecha</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >COMITÉ</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0a1c5_level0_row0" class="row_heading level0 row0" >Administración</th>
#       <td id="T_0a1c5_row0_col0" class="data row0 col0" >16.667</td>
#       <td id="T_0a1c5_row0_col1" class="data row0 col1" >83.333</td>
#       <td id="T_0a1c5_row0_col2" class="data row0 col2" >66.667</td>
#     </tr>
#     <tr>
#       <th id="T_0a1c5_level0_row1" class="row_heading level0 row1" >Agronomía y Forestal</th>
#       <td id="T_0a1c5_row1_col0" class="data row1 col0" >100.000</td>
#       <td id="T_0a1c5_row1_col1" class="data row1 col1" >0.000</td>
#       <td id="T_0a1c5_row1_col2" class="data row1 col2" >-100.000</td>
#     </tr>
#     <tr>
#       <th id="T_0a1c5_level0_row2" class="row_heading level0 row2" >Arquitectura</th>
#       <td id="T_0a1c5_row2_col0" class="data row2 col0" >100.000</td>
#       <td id="T_0a1c5_row2_col1" class="data row2 col1" >0.000</td>
#       <td id="T_0a1c5_row2_col2" class="data row2 col2" >-100.000</td>
#     </tr>
#     <tr>
#       <th id="T_0a1c5_level0_row3" class="row_heading level0 row3" >Arte</th>
#       <td id="T_0a1c5_row3_col0" class="data row3 col0" >50.000</td>
#       <td id="T_0a1c5_row3_col1" class="data row3 col1" >50.000</td>
#       <td id="T_0a1c5_row3_col2" class="data row3 col2" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_0a1c5_level0_row4" class="row_heading level0 row4" >Biología Celular y Molecular</th>
#       <td id="T_0a1c5_row4_col0" class="data row4 col0" >0.000</td>
#       <td id="T_0a1c5_row4_col1" class="data row4 col1" >100.000</td>
#       <td id="T_0a1c5_row4_col2" class="data row4 col2" >100.000</td>
#     </tr>
#     <tr>
#       <th id="T_0a1c5_level0_row5" class="row_heading level0 row5" >Biología Fisiológica y Bioquímica</th>
#       <td id="T_0a1c5_row5_col0" class="data row5 col0" >50.000</td>
#       <td id="T_0a1c5_row5_col1" class="data row5 col1" >50.000</td>
#       <td id="T_0a1c5_row5_col2" class="data row5 col2" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_0a1c5_level0_row6" class="row_heading level0 row6" >Biotecnología</th>
#       <td id="T_0a1c5_row6_col0" class="data row6 col0" >66.667</td>
#       <td id="T_0a1c5_row6_col1" class="data row6 col1" >33.333</td>
#       <td id="T_0a1c5_row6_col2" class="data row6 col2" >-33.333</td>
#     </tr>
#     <tr>
#       <th id="T_0a1c5_level0_row7" class="row_heading level0 row7" >Computación e Informática</th>
#       <td id="T_0a1c5_row7_col0" class="data row7 col0" >50.000</td>
#       <td id="T_0a1c5_row7_col1" class="data row7 col1" >50.000</td>
#       <td id="T_0a1c5_row7_col2" class="data row7 col2" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_0a1c5_level0_row8" class="row_heading level0 row8" >Cs. Matemáticas</th>
#       <td id="T_0a1c5_row8_col0" class="data row8 col0" >0.000</td>
#       <td id="T_0a1c5_row8_col1" class="data row8 col1" >100.000</td>
#       <td id="T_0a1c5_row8_col2" class="data row8 col2" >100.000</td>
#     </tr>
#     <tr>
#       <th id="T_0a1c5_level0_row9" class="row_heading level0 row9" >Cs. Médicas</th>
#       <td id="T_0a1c5_row9_col0" class="data row9 col0" >53.846</td>
#       <td id="T_0a1c5_row9_col1" class="data row9 col1" >46.154</td>
#       <td id="T_0a1c5_row9_col2" class="data row9 col2" >-7.692</td>
#     </tr>
#     <tr>
#       <th id="T_0a1c5_level0_row10" class="row_heading level0 row10" >Cs. Políticas y Estudios Internacionales</th>
#       <td id="T_0a1c5_row10_col0" class="data row10 col0" >42.857</td>
#       <td id="T_0a1c5_row10_col1" class="data row10 col1" >57.143</td>
#       <td id="T_0a1c5_row10_col2" class="data row10 col2" >14.286</td>
#     </tr>
#     <tr>
#       <th id="T_0a1c5_level0_row11" class="row_heading level0 row11" >Cs. de la Ingeniería I</th>
#       <td id="T_0a1c5_row11_col0" class="data row11 col0" >33.333</td>
#       <td id="T_0a1c5_row11_col1" class="data row11 col1" >66.667</td>
#       <td id="T_0a1c5_row11_col2" class="data row11 col2" >33.333</td>
#     </tr>
#     <tr>
#       <th id="T_0a1c5_level0_row12" class="row_heading level0 row12" >Cs. de la Ingeniería II</th>
#       <td id="T_0a1c5_row12_col0" class="data row12 col0" >25.000</td>
#       <td id="T_0a1c5_row12_col1" class="data row12 col1" >75.000</td>
#       <td id="T_0a1c5_row12_col2" class="data row12 col2" >50.000</td>
#     </tr>
#     <tr>
#       <th id="T_0a1c5_level0_row13" class="row_heading level0 row13" >Derecho</th>
#       <td id="T_0a1c5_row13_col0" class="data row13 col0" >35.000</td>
#       <td id="T_0a1c5_row13_col1" class="data row13 col1" >65.000</td>
#       <td id="T_0a1c5_row13_col2" class="data row13 col2" >30.000</td>
#     </tr>
#     <tr>
#       <th id="T_0a1c5_level0_row14" class="row_heading level0 row14" >Diseño</th>
#       <td id="T_0a1c5_row14_col0" class="data row14 col0" >100.000</td>
#       <td id="T_0a1c5_row14_col1" class="data row14 col1" >0.000</td>
#       <td id="T_0a1c5_row14_col2" class="data row14 col2" >-100.000</td>
#     </tr>
#     <tr>
#       <th id="T_0a1c5_level0_row15" class="row_heading level0 row15" >Ecología y Ciencias Naturales</th>
#       <td id="T_0a1c5_row15_col0" class="data row15 col0" >50.000</td>
#       <td id="T_0a1c5_row15_col1" class="data row15 col1" >50.000</td>
#       <td id="T_0a1c5_row15_col2" class="data row15 col2" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_0a1c5_level0_row16" class="row_heading level0 row16" >Economía</th>
#       <td id="T_0a1c5_row16_col0" class="data row16 col0" >50.000</td>
#       <td id="T_0a1c5_row16_col1" class="data row16 col1" >50.000</td>
#       <td id="T_0a1c5_row16_col2" class="data row16 col2" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_0a1c5_level0_row17" class="row_heading level0 row17" >Educación I</th>
#       <td id="T_0a1c5_row17_col0" class="data row17 col0" >75.000</td>
#       <td id="T_0a1c5_row17_col1" class="data row17 col1" >25.000</td>
#       <td id="T_0a1c5_row17_col2" class="data row17 col2" >-50.000</td>
#     </tr>
#     <tr>
#       <th id="T_0a1c5_level0_row18" class="row_heading level0 row18" >Educación II</th>
#       <td id="T_0a1c5_row18_col0" class="data row18 col0" >64.706</td>
#       <td id="T_0a1c5_row18_col1" class="data row18 col1" >35.294</td>
#       <td id="T_0a1c5_row18_col2" class="data row18 col2" >-29.412</td>
#     </tr>
#     <tr>
#       <th id="T_

# %%
OCDE = df_doc[df_doc['ESTADO_FINAL'] == 'SELECCIONADA'].groupby(['Área OCDE',])['GÉNERO'].value_counts().unstack(1).fillna(0).astype(int)
OCDE['Brecha (adm)'] = OCDE['Masculino'] - OCDE['Femenino'] 
OCDE.style.background_gradient(cmap= 'YlOrRd', subset=['Brecha (sel)'])
# Out:
# <style type="text/css">
# #T_73e1c_row0_col2, #T_73e1c_row1_col2, #T_73e1c_row4_col2 {
#   background-color: #c10325;
#   color: #f1f1f1;
# }
# #T_73e1c_row2_col2 {
#   background-color: #b70026;
#   color: #f1f1f1;
# }
# #T_73e1c_row3_col2 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_73e1c_row5_col2 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_73e1c_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >GÉNERO</th>
#       <th class="col_heading level0 col0" >Femenino</th>
#       <th class="col_heading level0 col1" >Masculino</th>
#       <th class="col_heading level0 col2" >Brecha (adm)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Área OCDE</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_73e1c_level0_row0" class="row_heading level0 row0" >CIENCIAS AGRICOLAS</th>
#       <td id="T_73e1c_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_73e1c_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_73e1c_row0_col2" class="data row0 col2" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_73e1c_level0_row1" class="row_heading level0 row1" >CIENCIAS MEDICAS Y DE SALUD</th>
#       <td id="T_73e1c_row1_col0" class="data row1 col0" >7</td>
#       <td id="T_73e1c_row1_col1" class="data row1 col1" >6</td>
#       <td id="T_73e1c_row1_col2" class="data row1 col2" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_73e1c_level0_row2" class="row_heading level0 row2" >CIENCIAS NATURALES</th>
#       <td id="T_73e1c_row2_col0" class="data row2 col0" >14</td>
#       <td id="T_73e1c_row2_col1" class="data row2 col1" >14</td>
#       <td id="T_73e1c_row2_col2" class="data row2 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_73e1c_level0_row3" class="row_heading level0 row3" >CIENCIAS SOCIALES</th>
#       <td id="T_73e1c_row3_col0" class="data row3 col0" >80</td>
#       <td id="T_73e1c_row3_col1" class="data row3 col1" >42</td>
#       <td id="T_73e1c_row3_col2" class="data row3 col2" >-38</td>
#     </tr>
#     <tr>
#       <th id="T_73e1c_level0_row4" class="row_heading level0 row4" >HUMANIDADES</th>
#       <td id="T_73e1c_row4_col0" class="data row4 col0" >17</td>
#       <td id="T_73e1c_row4_col1" class="data row4 col1" >16</td>
#       <td id="T_73e1c_row4_col2" class="data row4 col2" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_73e1c_level0_row5" class="row_heading level0 row5" >INGENIERIA Y TECNOLOGIA</th>
#       <td id="T_73e1c_row5_col0" class="data row5 col0" >2</td>
#       <td id="T_73e1c_row5_col1" class="data row5 col1" >7</td>
#       <td id="T_73e1c_row5_col2" class="data row5 col2" >5</td>
#     </tr>
#   </tbody>
# </table>

# %%
OCDE = df_doc[df_doc['ESTADO_FINAL_NP'] == 'SELECCIONADA'].groupby(['Área OCDE'])['GÉNERO'].value_counts().unstack(1).fillna(0).astype(int)
OCDE['Brecha (adm)'] = OCDE['Masculino'] - OCDE['Femenino'] 
OCDE.style.background_gradient(cmap= 'YlOrRd', subset=['Brecha (sel)'])
# Out:
# <style type="text/css">
# #T_e6eec_row0_col2, #T_e6eec_row1_col2 {
#   background-color: #c50624;
#   color: #f1f1f1;
# }
# #T_e6eec_row2_col2 {
#   background-color: #a40026;
#   color: #f1f1f1;
# }
# #T_e6eec_row3_col2 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_e6eec_row4_col2 {
#   background-color: #bd0026;
#   color: #f1f1f1;
# }
# #T_e6eec_row5_col2 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e6eec_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >GÉNERO</th>
#       <th class="col_heading level0 col0" >Femenino</th>
#       <th class="col_heading level0 col1" >Masculino</th>
#       <th class="col_heading level0 col2" >Brecha (adm)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Área OCDE</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e6eec_level0_row0" class="row_heading level0 row0" >CIENCIAS AGRICOLAS</th>
#       <td id="T_e6eec_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_e6eec_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_e6eec_row0_col2" class="data row0 col2" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_e6eec_level0_row1" class="row_heading level0 row1" >CIENCIAS MEDICAS Y DE SALUD</th>
#       <td id="T_e6eec_row1_col0" class="data row1 col0" >7</td>
#       <td id="T_e6eec_row1_col1" class="data row1 col1" >6</td>
#       <td id="T_e6eec_row1_col2" class="data row1 col2" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_e6eec_level0_row2" class="row_heading level0 row2" >CIENCIAS NATURALES</th>
#       <td id="T_e6eec_row2_col0" class="data row2 col0" >13</td>
#       <td id="T_e6eec_row2_col1" class="data row2 col1" >15</td>
#       <td id="T_e6eec_row2_col2" class="data row2 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_e6eec_level0_row3" class="row_heading level0 row3" >CIENCIAS SOCIALES</th>
#       <td id="T_e6eec_row3_col0" class="data row3 col0" >81</td>
#       <td id="T_e6eec_row3_col1" class="data row3 col1" >47</td>
#       <td id="T_e6eec_row3_col2" class="data row3 col2" >-34</td>
#     </tr>
#     <tr>
#       <th id="T_e6eec_level0_row4" class="row_heading level0 row4" >HUMANIDADES</th>
#       <td id="T_e6eec_row4_col0" class="data row4 col0" >16</td>
#       <td id="T_e6eec_row4_col1" class="data row4 col1" >16</td>
#       <td id="T_e6eec_row4_col2" class="data row4 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e6eec_level0_row5" class="row_heading level0 row5" >INGENIERIA Y TECNOLOGIA</th>
#       <td id="T_e6eec_row5_col0" class="data row5 col0" >2</td>
#       <td id="T_e6eec_row5_col1" class="data row5 col1" >7</td>
#       <td id="T_e6eec_row5_col2" class="data row5 col2" >5</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_doc.groupby('DELTA')['ESTADO_FINAL'].value_counts().to_frame()
# Out:
#                                 ESTADO_FINAL
# DELTA          ESTADO_FINAL
# BAJA           SELECCIONADA               75
#                NO SELECCIONADA            45
# FUERA DE BASES FUERA DE BASES             45
# MANTIENE       SELECCIONADA                2
# SUBE           SELECCIONADA              129
#                NO SELECCIONADA            65

# %%
df_doc.groupby('DELTA')['ESTADO_FINAL_NP'].value_counts().to_frame()
# Out:
#                                 ESTADO_FINAL_NP
# DELTA          ESTADO_FINAL_NP
# BAJA           SELECCIONADA                  72
#                NO SELECCIONADA               48
# FUERA DE BASES FUERA DE BASES                45
# MANTIENE       SELECCIONADA                   2
# SUBE           SELECCIONADA                 137
#                NO SELECCIONADA               57

# %%
df_doc[df_doc['ESTADO ADMISIBILIDAD'] != 'FUERA DE BASES'].groupby(['COMITÉ'])['DELTA'].value_counts().to_frame()
# Out:
#                                                          DELTA
# COMITÉ                                         DELTA
# Administración                                 SUBE          5
#                                                BAJA          2
# Agronomía y Forestal                           BAJA          2
# Arquitectura                                   BAJA          3
#                                                SUBE          2
# Arte                                           SUBE          3
#                                                BAJA          2
#                                                MANTIENE      1
# Biología Celular y Molecular                   BAJA          1
#                                                SUBE          1
# Biología Fisiológica y Bioquímica              SUBE          2
#                                                BAJA          1
# Biotecnología                                  SUBE          3
# Computación e Informática                      SUBE          2
# Cs. Matemáticas                                SUBE          3
#                                                BAJA          1
# Cs. Médicas                                    SUBE         14
#                                                BAJA          8
# Cs. Políticas y Estudios Internacionales       BAJA          5
#                                                SUBE          2
#                                                MANTIENE      1
# Cs. Veterinarias                               SUBE          1
# Cs. de la Ingeniería I                         SUBE          6
#                                                BAJA          2
# Cs. de la Ingeniería II                        SUBE          6
#                                                BAJA          4
# Derecho                                        SUBE         13
#                                                BAJA         11
# Diseño                                         SUBE          2
#                                                BAJA          1
# Ecología y Ciencias Naturales                  BAJA          6
#                                                SUBE          5
# Economía                                       SUBE          6
#                                                BAJA          4
# Educación I                                    SUBE         26
#                                                BAJA         20
# Educación II                                   SUBE         20
#                                                BAJA         10
# Filosofía                                      SUBE          6
#                                                BAJA          3
# Física y Astronomía                            SUBE          3
# Geología y Oceanografía                        BAJA          6
#                                                SUBE          5
# Historia, Antropología y Arqueología           SUBE         13
#                                                BAJA          6
# Letras                                         SUBE          6
#                                                BAJA          5
# Políticas Públicas y Administración del Estado SUBE          7
#                                                BAJA          3
# Psicología                                     SUBE         10
#                                                BAJA          4
# Sociología                                     SUBE         14
#                                                BAJA          4
# Urbanismo y Asentamientos Humanos              SUBE          8
#                                                BAJA          6

# %%
df_doc['DELTA'].value_counts().to_frame()
# Out:
#                 DELTA
# SUBE              194
# BAJA              120
# FUERA DE BASES     45
# MANTIENE            2

# %%
df_doc[df_doc['ESTADO ADMISIBILIDAD'] != 'FUERA DE BASES'].groupby(['COMITÉ','ESTADO_FINAL','ESTADO_FINAL_NP'])['DELTA'].value_counts().to_frame()
# Out:
#                                                                                          DELTA
# COMITÉ                                         ESTADO_FINAL    ESTADO_FINAL_NP DELTA
# Administración                                 NO SELECCIONADA NO SELECCIONADA BAJA          1
#                                                                SELECCIONADA    SUBE          2
#                                                SELECCIONADA    SELECCIONADA    SUBE          3
#                                                                                BAJA          1
# Agronomía y Forestal                           NO SELECCIONADA NO SELECCIONADA BAJA          1
#                                                SELECCIONADA    SELECCIONADA    BAJA          1
# Arquitectura                                   NO SELECCIONADA NO SELECCIONADA SUBE          2
#                                                SELECCIONADA    NO SELECCIONADA BAJA          1
#                                                                SELECCIONADA    BAJA          2
# Arte                                           NO SELECCIONADA NO SELECCIONADA BAJA          1
#                                                                                SUBE          1
#                                                SELECCIONADA    SELECCIONADA    SUBE          2
#                                                                                BAJA          1
#                                                                                MANTIENE      1
# Biología Celular y Molecular                   NO SELECCIONADA NO SELECCIONADA BAJA          1
#                                                SELECCIONADA    SELECCIONADA    SUBE          1
# Biología Fisiológica y Bioquímica              NO SELECCIONADA NO SELECCIONADA SUBE          1
#                                                SELECCIONADA    SELECCIONADA    BAJA          1
#                                                                                SUBE          1
# Biotecnología                                  NO SELECCIONADA SELECCIONADA    SUBE          1
#                                                SELECCIONADA    SELECCIONADA    SUBE          2
# Computación e Informática                      SELECCIONADA    SELECCIONADA    SUBE          2
# Cs. Matemáticas                                SELECCIONADA    SELECCIONADA    SUBE          3
#                                                                                BAJA          1
# Cs. Médicas                                    NO SELECCIONADA NO SELECCIONADA BAJA          5
#                                                                                SUBE          4
#                                                SELECCIONADA    SELECCIONADA    SUBE         10
#                                                                                BAJA          3
# Cs. Políticas y Estudios Internacionales       NO SELECCIONADA NO SELECCIONADA SUBE          1
#                                                SELECCIONADA    SELECCIONADA    BAJA          5
#                                                                                MANTIENE      1
#                                                                                SUBE          1
# Cs. Veterinarias                               NO SELECCIONADA NO SELECCIONADA SUBE          1
# Cs. de la Ingeniería I                         NO SELECCIONADA NO SELECCIONADA BAJA          1
#                                                                                SUBE          1
#                                                SELECCIONADA    SELECCIONADA    SUBE          5
#                                                                                BAJA          1
# Cs. de la Ingeniería II                        NO SELECCIONADA NO SELECCIONADA BAJA          3
#                                                                                SUBE          3
#                                                SELECCIONADA    SELECCIONADA    SUBE          3
#                                                                                BAJA          1
# Derecho                                        NO SELECCIONADA NO SELECCIONADA BAJA          3
#                                                                SELECCIONADA    SUBE          1
#                                                SELECCIONADA    NO SELECCIONADA BAJA          1
#                                                                SELECCIONADA    SUBE         12
#                                                                                BAJA          7
# Diseño                                         NO SELECCIONADA NO SELECCIONADA BAJA          1
#                                                                                SUBE          1
#                                                SELECCIONADA    SELECCIONADA    SUBE          1
# Ecología y Ciencias Naturales                  NO SELECCIONADA NO SELECCIONADA SUBE          2
#                                                                                BAJA          1
#                                                SELECCIONADA    SELECCIONADA    BAJA          5
#                                                                                SUBE          3
# Economía                                       NO SELECCIONADA NO SELECCIONADA BAJA          2
#                                                                SELECCIONADA    SUBE          1
#                                                SELECCIONADA    SELECCIONADA    SUBE          5
#                                                                                BAJA          2
# Educación I                                    NO SELECCIONADA NO SELECCIONADA BAJA          7
#                                                                                SUBE          7
#                                                SELECCIONADA    SELECCIONADA    SUBE         19
#                                                                                BAJA         13
# Educación II                                   NO SELECCIONADA NO SELECCIONADA SUBE         10
#                                                                                BAJA          3
#                                                                SELECCIONADA    SUBE          2
#                                                SELECCIONADA    SELECCIONADA    SUBE          8
#                                                                                BAJA          7
# Filosofía                                      NO SELECCIONADA NO SELECCIONADA BAJA          2
#                                                                                SUBE          1
#                                                SELECCIONADA    SELECCIONADA    SUBE          5
#                                                                                BAJA          1
# Física y Astronomía                            SELECCIONADA    SELECCIONADA    SUBE          3
# Geología y Oceanografía                        NO SELECCIONADA NO SELECCIONADA BAJA          3
#                                                                                SUBE          3
#                                                SELECCIONADA    NO SELECCIONADA BAJA          1
#                                                                SELECCIONADA    BAJA          2
#                                                                                SUBE          2
# Historia, Antropología y Arqueología           NO SELECCIONADA NO SELECCIONADA SUBE          4
#                                                                                BAJA          2
#                                                SELECCIONADA    SELECCIONADA    SUBE          9
#                                                                                BAJA          4
# Letras                                         NO SELECCIONADA NO SELECCIONADA BAJA          3
#                                                                                SUBE          2
#                                                SELECCIONADA    SELECCIONADA    SUBE          4
#                                                                                BAJA          2
# Políticas Públicas y Administración del Estado NO SELECCIONADA NO SELECCIONADA SUBE          2
#                                                                                BAJA          1
#                                                SELECCIONADA    SELECCIONADA    SUBE          5
#                                                                                BAJA          2
# Psicología                                     NO SELECCIONADA NO SELECCIONADA SUBE          4
#                                                                                BAJA          1
#                                                SELECCIONADA    SELECCIONADA    SUBE          6
#                                                                                BAJA          3
# Sociología                                     NO SELECCIONADA NO SELECCIONADA SUBE          4
#                                                                                BAJA          1
#                                                SELECCIONADA    SELECCIONADA    SUBE         10
#                                                                                BAJA          3
# Urbanismo y Asentamientos Humanos              NO SELECCIONADA NO SELECCIONADA SUBE          3
#                                                                                BAJA          2
#                                                                SELECCIONADA    SUBE          1
#                                                SELECCIONADA    SELECCIONADA    BAJA          4
#                                                                                SUBE          4

# %%
df_doc[df_doc['ESTADO ADMISIBILIDAD'] != 'FUERA DE BASES'].groupby(['COMITÉ','ESTADO_FINAL','ESTADO_FINAL_NP','DELTA'])['GÉNERO'].value_counts().unstack(4).fillna(0).astype(int)
# Out:
# GÉNERO                                                                                   Femenino  \
# COMITÉ                                         ESTADO_FINAL    ESTADO_FINAL_NP DELTA
# Administración                                 NO SELECCIONADA NO SELECCIONADA BAJA             1
#                                                                SELECCIONADA    SUBE             0
#                                                SELECCIONADA    SELECCIONADA    BAJA             1
#                                                                                SUBE             0
# Agronomía y Forestal                           NO SELECCIONADA NO SELECCIONADA BAJA             0
#                                                SELECCIONADA    SELECCIONADA    BAJA             1
# Arquitectura                                   NO SELECCIONADA NO SELECCIONADA SUBE             1
#                                                SELECCIONADA    NO SELECCIONADA BAJA             1
#                                                                SELECCIONADA    BAJA             2
# Arte                                           NO SELECCIONADA NO SELECCIONADA BAJA             1
#                                                                                SUBE             1
#                                                SELECCIONADA    SELECCIONADA    BAJA             1
#                                                                                MANTIENE         0
#                                                                                SUBE             1
# Biología Celular y Molecular                   NO SELECCIONADA NO SELECCIONADA BAJA             0
#                                                SELECCIONADA    SELECCIONADA    SUBE             0
# Biología Fisiológica y Bioquímica              NO SELECCIONADA NO SELECCIONADA SUBE             0
#                                                SELECCIONADA    SELECCIONADA    BAJA             0
#                                                                                SUBE             1
# Biotecnología                                  NO SELECCIONADA SELECCIONADA    SUBE             0
#                                                SELECCIONADA    SELECCIONADA    SUBE             2
# Computación e Informática                      SELECCIONADA    SELECCIONADA    SUBE             1
# Cs. Matemáticas                                SELECCIONADA    SELECCIONADA    BAJA             0
#                                                                                SUBE             0
# Cs. Médicas                                    NO SELECCIONADA NO SELECCIONADA BAJA             1
#                                                                                SUBE             1
#                                                SELECCIONADA    SELECCIONADA    BAJA             1
#                                                                                SUBE             6
# Cs. Políticas y Estudios Internacionales       NO SELECCIONADA NO SELECCIONADA SUBE             1
#                                                SELECCIONADA    SELECCIONADA    BAJA             2
#                                                                                MANTIENE         1
#                                                                                SUBE             0
# Cs. Veterinarias                               NO SELECCIONADA NO SELECCIONADA SUBE             1
# Cs. de la Ingeniería I                         NO SELECCIONADA NO SELECCIONADA BAJA             0
#                                                                                SUBE             0
#                                                SELECCIONADA    SELECCIONADA    BAJA             0
#                                                                                SUBE             2
# Cs. de la Ingeniería II                        NO SELECCIONADA NO SELECCIONADA BAJA             0
#                                                                                SUBE             0
#                                                SELECCIONADA    SELECCIONADA    BAJA             0
#                                                                                SUBE             1
# Derecho                                        NO SELECCIONADA NO SELECCIONADA BAJA             0
#                                                                SELECCIONADA    SUBE             0
#                                                SELECCIONADA    NO SELECCIONADA BAJA             1
#                                                                SELECCIONADA    BAJA             2
#                                                                                SUBE             5
# Diseño                                         NO SELECCIONADA NO SELECCIONADA BAJA             1
#                                                                                SUBE             1
#                                                SELECCIONADA    SELECCIONADA    SUBE             1
# Ecología y Ciencias Naturales                  NO SELECCIONADA NO SELECCIONADA BAJA             1
#                                                                                SUBE             1
#                                                SELECCIONADA    SELECCIONADA    BAJA             2
#                                                                                SUBE             2
# Economía                                       NO SELECCIONADA NO SELECCIONADA BAJA             0
#                                                                SELECCIONADA    SUBE             1
#                                                SELECCIONADA    SELECCIONADA    BAJA             1
#                                                                                SUBE             2
# Educación I                                    NO SELECCIONADA NO SELECCIONADA BAJA             5
#                                                                                SUBE             3
#                                                SELECCIONADA    SELECCIONADA    BAJA             9
#                                                                                SUBE            15
# Educación II                                   NO SELECCIONADA NO SELECCIONADA BAJA             2
#                                                                                SUBE             6
#                                                                SELECCIONADA    SUBE             1
#                                                SELECCIONADA    SELECCIONADA    BAJA             4
#                                                                                SUBE             6
# Filosofía                                      NO SELECCIONADA NO SELECCIONADA BAJA             0
#                                                                                SUBE             0
#                                                SELECCIONADA    SELECCIONADA    BAJA             1
#                                                                                SUBE             1
# Física y Astronomía                            SELECCIONADA    SELECCIONADA    SUBE             2
# Geología y Oceanografía                        NO SELECCIONADA NO SELECCIONADA BAJA             2
#                                                                                SUBE             1
#                                                SELECCIONADA    NO SELECCIONADA BAJA             1
#                                                                SELECCIONADA    BAJA             1
#                                                                                SUBE             1
# Historia, Antropología y Arqueología           NO SELECCIONADA NO SELECCIONADA BAJA             0
#                                                                                SUBE             2
#                                                SELECCIONADA    SELECCIONADA    BAJA             2
#                                                                                SUBE             6
# Letras                                         NO SELECCIONADA NO SELECCIONADA BAJA             1
#                                                                                SUBE             2
#                                                SELECCIONADA    SELECCIONADA    BAJA             0
#                                                                                SUBE             1
# Políticas Públicas y Administración del Estado NO SELECCIONADA NO SELECCIONADA BAJA             1
#                                                                                SUBE             0
#                                                SELECCIONADA    SELECCIONADA    BAJA             0
#                                                                                SUBE             5
# Psicología                                     NO SELECCIONADA NO SELECCIONADA BAJA             0
#                                                                                SUBE             2
#                                                SELECCIONADA    SELECCIONADA    BAJA             3
#                                                                                SUBE             6
# Sociología                                     NO SELECCIONADA NO SELECCIONADA BAJA             0
#                                                                                SUBE             4
#                                                SELECCIONADA    SELECCIONADA    BAJA             3
#                                                                                SUBE             8
# Urbanismo y Asentamientos Humanos              NO SELECCIONADA NO SELECCIONADA BAJA             1
#                                                                                SUBE             1
#                                                                SELECCIONADA    SUBE             0
#                                                SELECCIONADA    SELECCIONADA    BAJA             3
#                                                                                SUBE             3
#
# GÉNERO                                                                                   Masculino
# COMITÉ                                         ESTADO_FINAL    ESTADO_FINAL_NP DELTA
# Administración                                 NO SELECCIONADA NO SELECCIONADA BAJA              0
#                                                                SELECCIONADA    SUBE              2
#                                                SELECCIONADA    SELECCIONADA    BAJA              0
#                                                                                SUBE              3
# Agronomía y Forestal                           NO SELECCIONADA NO SELECCIONADA BAJA              1
#                                                SELECCIONADA    SELECCIONADA    BAJA              0
# Arquitectura                                   NO SELECCIONADA NO SELECCIONADA SUBE              1
#                                                SELECCIONADA    NO SELECCIONADA BAJA              0
#                                                                SELECCIONADA    BAJA              0
# Arte                                           NO SELECCIONADA NO SELECCIONADA BAJA              0
#                                                                                SUBE              0
#                                                SELECCIONADA    SELECCIONADA    BAJA              0
#                                                                                MANTIENE          1
#                                                                                SUBE              1
# Biología Celular y Molecular                   NO SELECCIONADA NO SELECCIONADA BAJA              1
#                                                SELECCIONADA    SELECCIONADA    SUBE              1
# Biología Fisiológica y Bioquímica              NO SELECCIONADA NO SELECCIONADA SUBE              1
#                                                SELECCIONADA    SELECCIONADA    BAJA              1
#                                                                                SUBE              0
# Biotecnología                                  NO SELECCIONADA SELECCIONADA    SUBE              1
#                                                SELECCIONADA    SELECCIONADA    SUBE              0
# Computación e Informática                      SELECCIONADA    SELECCIONADA    SUBE              1
# Cs. Matemáticas                                SELECCIONADA    SELECCIONADA    BAJA              1
#                                                                                SUBE              3
# Cs. Médicas                                    NO SELECCIONADA NO SELECCIONADA BAJA              4
#                                                                                SUBE              3
#                                                SELECCIONADA    SELECCIONADA    BAJA              2
#                                                                                SUBE              4
# Cs. Políticas y Estudios Internacionales       NO SELECCIONADA NO SELECCIONADA SUBE              0
#                                                SELECCIONADA    SELECCIONADA    BAJA              3
#                                                                                MANTIENE          0
#                                                                                SUBE              1
# Cs. Veterinarias                               NO SELECCIONADA NO SELECCIONADA SUBE              0
# Cs. de la Ingeniería I                         NO SELECCIONADA NO SELECCIONADA BAJA              1
#                                                                                SUBE              1
#                                                SELECCIONADA    SELECCIONADA    BAJA              1
#                                                                                SUBE              3
# Cs. de la Ingeniería II                        NO SELECCIONADA NO SELECCIONADA BAJA              3
#                                                                                SUBE              3
#                                                SELECCIONADA    SELECCIONADA    BAJA              1
#                                                                                SUBE              2
# Derecho                                        NO SELECCIONADA NO SELECCIONADA BAJA              3
#                                                                SELECCIONADA    SUBE              1
#                                                SELECCIONADA    NO SELECCIONADA BAJA              0
#                                                                SELECCIONADA    BAJA              5
#                                                                                SUBE              7
# Diseño                                         NO SELECCIONADA NO SELECCIONADA BAJA              0
#                                                                                SUBE              0
#                                                SELECCIONADA    SELECCIONADA    SUBE              0
# Ecología y Ciencias Naturales                  NO SELECCIONADA NO SELECCIONADA BAJA              0
#                                                                                SUBE              1
#                                                SELECCIONADA    SELECCIONADA    BAJA              3
#                                                                                SUBE              1
# Economía                                       NO SELECCIONADA NO SELECCIONADA BAJA              2
#                                                                SELECCIONADA    SUBE              0
#                                                SELECCIONADA    SELECCIONADA    BAJA              1
#                                                                                SUBE              3
# Educación I                                    NO SELECCIONADA NO SELECCIONADA BAJA              2
#                                                                                SUBE              4
#                                                SELECCIONADA    SELECCIONADA    BAJA              4
#                                                                                SUBE              4
# Educación II                                   NO SELECCIONADA NO SELECCIONADA BAJA              1
#                                                                                SUBE              4
#                                                                SELECCIONADA    SUBE              1
#                                                SELECCIONADA    SELECCIONADA    BAJA              3
#                                                                                SUBE              2
# Filosofía                                      NO SELECCIONADA NO SELECCIONADA BAJA              2
#                                                                                SUBE              1
#                                                SELECCIONADA    SELECCIONADA    BAJA              0
#                                                                                SUBE              4
# Física y Astronomía                            SELECCIONADA    SELECCIONADA    SUBE              1
# Geología y Oceanografía                        NO SELECCIONADA NO SELECCIONADA BAJA              1
#                                                                                SUBE              2
#                                                SELECCIONADA    NO SELECCIONADA BAJA              0
#                                                                SELECCIONADA    BAJA              1
#                                                                                SUBE              1
# Historia, Antropología y Arqueología           NO SELECCIONADA NO SELECCIONADA BAJA              2
#                                                                                SUBE              2
#                                                SELECCIONADA    SELECCIONADA    BAJA              2
#                                                                                SUBE              3
# Letras                                         NO SELECCIONADA NO SELECCIONADA BAJA              2
#                                                                                SUBE              0
#                                                SELECCIONADA    SELECCIONADA    BAJA              2
#                                                                                SUBE              3
# Políticas Públicas y Administración del Estado NO SELECCIONADA NO SELECCIONADA BAJA              0
#                                                                                SUBE              2
#                                                SELECCIONADA    SELECCIONADA    BAJA              2
#                                                                                SUBE              0
# Psicología                                     NO SELECCIONADA NO SELECCIONADA BAJA              1
#                                                                                SUBE              2
#                                                SELECCIONADA    SELECCIONADA    BAJA              0
#                                                                                SUBE              0
# Sociología                                     NO SELECCIONADA NO SELECCIONADA BAJA              1
#                                                                                SUBE              0
#                                                SELECCIONADA    SELECCIONADA    BAJA              0
#                                                                                SUBE              2
# Urbanismo y Asentamientos Humanos              NO SELECCIONADA NO SELECCIONADA BAJA              1
#                                                                                SUBE              2
#                                                                SELECCIONADA    SUBE              1
#                                                SELECCIONADA    SELECCIONADA    BAJA              1
#                                                                                SUBE              1
